# %% [markdown]
# ## WELCOME

# %% [markdown]
# #### This is an introductory guide to the Riot API

# %% [markdown]
# Have you ever wondered how sites like u.gg and op.gg get their data? \
# Are you looking to become an esports analyst but not sure what skills you need? \
# Want to create an app or site but not sure how to build one?
#
# All these questions can be answered the same: The Riot API
#
# In this short introductory guide I will take you through the process of building your first ever Riot API product \
# It will require some very basic Python knowledge, but I'll explain every step along the way
#
# I hope you enjoy,
#
# Jack J \
# Founder & Lead Data Scientist @ iTero Gaming

# %% [markdown]
# ### New to Python?

# %% [markdown]
# The tutorial doesn't require you to do any coding. Technically, you can do this all with zero knowledge \
# Even so, you may want to learn more about how it works. \
# There's 1000s of really good Python guides free on the internet, so I won't waste time writing another one \
# I suggest going along with this tutorial and Googling certain areas where you're not sure what's happening \
# If you have any questions, you could always join the Discord and ask one of the many knowledgeable persons there!
#
# You run each cell (the grey ones with the square brackets on the left, like the one below) by first clicking into it and EITHER \
# Press "Run" (top bar above) \
# OR press Ctrl + Enter \
# OR press Alt + Enter, which will run the cell AND create a new empty one below it
#
# Have a test on the cell below

# %%
print("hello computer don't you worry i'm just learning Python")
# Out:
# hello computer don't you worry i'm just learning Python

# %% [markdown]
# ### Getting a key

# %% [markdown]
# Head over to https://developer.riotgames.com/ \
# Login with your Riot Account and accept the terms of service \
# At the bottom, click "I'm not a Robot" and regenerate your API key \
# Copy the API key below

# %%
api_key = "RGAPI-3ee6f984-bd4e-43fe-a855-51c08b131105"

# %% [markdown]
# ### Our First API Call

# %% [markdown]
# Go back to the developer portal and at the top, click "APIS" \
# On the left there will be a list of all the available APIs that Riot offers \
# Don't be overwhelmed, it covers most of their games and we will only need a small number of them
#
# Scroll down until you find "Summoner-V4", once you click it you will see a list of API calls in the middle \
# From here, click on the API called: /lol/summoner/v4/summoners/by-name/{summonerName} \
# Scroll to the bottom of the page and type in your Summoner Name, select your Region and then select Development API Key \
# Then, click "EXECUTE REQUEST"
#
# You should see a response code of 200, then below that the Response Body with information about your account
#
# Scroll back up, just below "EXECUTE REQUEST" you will see a URL that looks something like the one below \
# Replace the below api_url with the one you have on the API portal

# %%
api_url = "https://la1.api.riotgames.com/lol/summoner/v4/summoners/by-name/M0DEST0"

# %% [markdown]
# We will be managing all our API requests through the "requests" library, which should be pre-installed

# %%
import requests

# %% [markdown]
# We can then send off any API request we want, so let's send off our URL

# %%
requests.get(api_url)
# Out:
# <Response [401]>

# %% [markdown]
# 401?
#
# If you return to the portal and scroll up, you'll see a 401 error means: Unauthorized \
# That's because we haven't attached the API key to our request!
#
# When dealing with APIs, we tag on arguments to the request by adding "?" to the end of the url, followed by the variable

# %%
api_url = api_url + '?api_key=' + api_key

# %%
api_url
# Out:
# 'https://la1.api.riotgames.com/lol/summoner/v4/summoners/by-name/M0DEST0?api_key=RGAPI-3ee6f984-bd4e-43fe-a855-51c08b131105'

# %%
requests.get(api_url)
# Out:
# <Response [200]>

# %% [markdown]
# Great! Now we're getting a 200 (which means successful) \
# But where's the data? \
# To get it, we need to assign the request to a variable and call the JSON

# %%
resp = requests.get(api_url)
player_info = resp.json()
player_info
# Out:
# {'id': '0U_m8GUm6deRnrPronJ5o-8WYr3d1PprBttP_qlyfBIGjg',
#  'accountId': 'WCsPe0i_2CXPYDlr-GnWNdjl2ms85NKeMaweWf5lptvB2pk',
#  'puuid': 'ug6gjzUWzBgSY9Q2M4whHHKo_oyCatFoIuhcJHWwW6whTGrSutmObCCdtLGDqihAp5xaE7QlTAXuoQ',
#  'name': 'M0DEST0',
#  'profileIconId': 5497,
#  'revisionDate': 1700978571822,
#  'summonerLevel': 321}

# %% [markdown]
# And there we go! \
# We've successfully sent off and retrieved our first API request

# %% [markdown]
# #### Match Data

# %% [markdown]
# That was easy, but it's not much to show-off \
# The next thing we're going to do is get some historic match data
#
# To do this, go back to the portal and click "MATCH-V5" on the far left \
# Go the option called: /lol/match/v5/matches/by-puuid/{puuid}/ids \
# As we can see from the "{puuid}" above, it needs the accounts puuid - luckily we go that from the previous API!

# %%
puuid = player_info['puuid']
puuid
# Out:
# 'ug6gjzUWzBgSY9Q2M4whHHKo_oyCatFoIuhcJHWwW6whTGrSutmObCCdtLGDqihAp5xaE7QlTAXuoQ'

# %% [markdown]
# Scroll down on the portal until you see the box asking for the puuid \
# Copy and paste the puuid above into the "puuid" box \
# Leave the Query Parameters for now but update the REGION & then APP TO EXECUTE AGAINST to Development API Key \
# Execute Request!
#
# You should see a response code of 200, and the body contains a list of keys \
# Let's copy the REQUEST URL from the portal so we can get everything into Python

# %%
api_url = "https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/ug6gjzUWzBgSY9Q2M4whHHKo_oyCatFoIuhcJHWwW6whTGrSutmObCCdtLGDqihAp5xaE7QlTAXuoQ/ids?start=0&count=20"

# %% [markdown]
# If you inspect the URL, you'll see there's already arguments at the end: "?start=0&count=20"\
# In order to add another argument (your API key), we'll use the "&" symbol

# %%
#                    & instead of ?, because there's already a ? in the original
api_url = api_url + '&api_key=' + api_key 
api_url
# Out:
# 'https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/ug6gjzUWzBgSY9Q2M4whHHKo_oyCatFoIuhcJHWwW6whTGrSutmObCCdtLGDqihAp5xaE7QlTAXuoQ/ids?start=0&count=20&api_key=RGAPI-3ee6f984-bd4e-43fe-a855-51c08b131105'

# %% [markdown]
# Now, the same as before - let's get the data from this url

# %%
resp = requests.get(api_url)
match_ids = resp.json()

match_ids
# Out:
# ['LA1_1460596933',
#  'LA1_1460572182',
#  'LA1_1460549970',
#  'LA1_1460533557',
#  'LA1_1460494945',
#  'LA1_1459873188',
#  'LA1_1459871292',
#  'LA1_1459857257',
#  'LA1_1459837219',
#  'LA1_1459699435',
#  'LA1_1459689802',
#  'LA1_1459681842',
#  'LA1_1459675534',
#  'LA1_1459662989',
#  'LA1_1459642993',
#  'LA1_1458661840',
#  'LA1_1458641722',
#  'LA1_1458622715',
#  'LA1_1458611574',
#  'LA1_1458258515']

# %% [markdown]
# This API contains a list of the match IDs from our accounts last 20 games
#
# Let's take the first one of these

# %%
recent_match = match_ids[0]
recent_match
# Out:
# 'LA1_1460596933'

# %% [markdown]
# If we return to the portal, scroll back up and open this API: "/lol/match/v5/matches/{matchId}"
#
# Scroll down and copy the match ID into the "matchId" input, again selecting the right region & app
#
# If everything goes well, you'll see our trusty 200 response code and a lot of data in RESPONSE BODY
#
# Once again, copy and paste the REQUEST URL

# %%
api_url = "https://americas.api.riotgames.com/lol/match/v5/matches/LA1_1459873188"

# %%
# This one doesn't have any arguments (see, there's no "?" above) so we'll add it with the api key
api_url = api_url + '?api_key=' + api_key

# %%
resp = requests.get(api_url)
match_data = resp.json()

match_data
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'LA1_1459873188',
#   'participants': ['yzHjj7_866easD7HRZAJzQF_663UgPHo7Dr0oesjZdq0PiZvpcR7nudxVb7d43YRLT9kuNNWKJ_E5Q',
#    'aK3T5v83pPqbbIhH0yBAesMUK8O0UGl3NoEZWLN48tZfSkw9YqnzXFjZy8i_BJfQwVyIcWOWLJ3yZQ',
#    'bulof2FC0QvUjYVeUiM4vbXtL248d5C1OquqogaU993lCjCAWo5u8E_GFljnyyP0nl5-85X1Q5nZ9g',
#    'fC-3lKvs5r77swYG_qolaArnr9rba2fdVrDXTn6SuIm0FSVOgxGazPPHyOx3ceVOQyyNosykqKSXYg',
#    'JYPXADV1Xhnlq9y0BA4A2vTOBotFpLJP1qQW6Mt_2uVO9NXruJ7ATkZWhS52ateRHjZqn_P_3pznXw',
#    'ug6gjzUWzBgSY9Q2M4whHHKo_oyCatFoIuhcJHWwW6whTGrSutmObCCdtLGDqihAp5xaE7QlTAXuoQ',
#    '3GgmyGhFZN1ViTEot9NYaeNXQyMVdESpfYcpngXQFyRJv45wO5Lpo3IXLxcwRJtKmJqgzvFCtdo5vA',
#    'fDbSKld9q7WtYR8UJ_Emkuwg-ec17ZGndX-hfIjE9tbSNs-88Rwg4mYMQEdFFsmPLa6vub81HtKjvA',
#    'K27ooTlTnYuVRk-y8MUScFRui7P9tYN0GPoFMVJbOvGx_u-VmPyQO8RrZYTfH2Op-0h1Mej0VhEyVw',
#    '-4L801fRUAH_n6nUxYhH3K3-uTDCdZRWUxKv0IQzmj1rotZkGHP6sLcYIPTfwxGWYcfRY4JdObhowQ']},
#  'info': {'gameCreation': 1700814777035,
#   'gameDuration': 1839,
#   'gameEndTimestamp': 1700816724215,
#   'gameId': 1459873188,
#   'gameMode': 'CLASSIC',
#   'gameName': 'teambuilder-match-1459873188',
#   'gameStartTimestamp': 1700814884596,
#   'gameType': 'MATCHED_GAME',
#   'gameVersion': '13.23.544.5515',
#   'mapId': 11,
#   'participants': [{'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 6,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 4,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 394,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 1,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 1493.7438949999932,
#      'damageTakenOnTeamPercentage': 0.2476551301969414,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 6,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 1,
#      'earliestBaron': 1522.9802946999998,
#      'earliestDragonTakedown': 1411.9031631,
#      'earlyLaningPhaseGoldExpAdvantage': 1,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 57,
#      'enemyJungleMonsterKills': 12,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'flawlessAces': 1,
#      'fullTeamTakedown': 0,
#      'gameLength': 1839.9090887999998,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 546.6127536189495,
#      'hadOpenNexus': 0,
#      'highestChampionDamage': 1,
#      'highestWardKills': 1,
#      'immobilizeAndKillWithAlly': 7,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 2,
#      'kTurretsDestroyedBeforePlatesFall': 1,
#      'kda': 3.8333333333333335,
#      'killAfterHiddenWithAlly': 2,
#      'killParticipation': 0.575,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 3,
#      'killsNearEnemyTurret': 4,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 7,
#      'laneMinionsFirst10Minutes': 53,
#      'laningPhaseGoldExpAdvantage': 1,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 102.2000000178814,
#      'maxKillDeficit': 5,
#      'maxLevelLeadLaneOpponent': 3,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 5,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 3031,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 4,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 12,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 1,
#      'shortestTimeToAceFromFirstTakedown': 23.48775909999995,
#      'skillshotsDodged': 14,
#      'skillshotsHit': 28,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 6,
#      'stealthWardsPlaced': 6,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 23,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 2,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 1,
#      'teamDamagePercentage': 0.40049267407792444,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 5,
#      'turretTakedowns': 4,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.5244678258895874,
#      'visionScorePerMinute': 0.42809642360378936,
#      'wardTakedowns': 2,
#      'wardTakedownsBefore20M': 2,
#      'wardsGuarded': 0},
#     'champExperience': 17538,
#     'champLevel': 17,
#     'championId': 777,
#     'championName': 'Yone',
#     'championTransform': 0,
#     'commandPings': 5,
#     'consumablesPurchased': 1,
#     'damageDealtToBuildings': 6804,
#     'damageDealtToObjectives': 26475,
#     'damageDealtToTurrets': 6804,
#     'damageSelfMitigated': 30379,
#     'dangerPings': 0,
#     'deaths': 6,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 4,
#     'dragonKills': 1,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 10,
#     'enemyVisionPings': 1,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 2,
#     'goldEarned': 16761,
#     'goldSpent': 14300,
#     'holdPings': 0,
#     'individualPosition': 'TOP',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 3031,
#     'item1': 3153,
#     'item2': 3006,
#     'item3': 6673,
#     'item4': 6672,
#     'item5': 1055,
#     'item6': 3340,
#     'itemsPurchased': 23,
#     'killingSprees': 4,
#     'kills': 17,
#     'lane': 'JUNGLE',
#     'largestCriticalStrike': 3339,
#     'largestKillingSpree': 6,
#     'largestMultiKill': 3,
#     'longestTimeSpentLiving': 463,
#     'magicDamageDealt': 29239,
#     'magicDamageDealtToChampions': 7423,
#     'magicDamageTaken': 9271,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 27,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 5,
#     'participantId': 1,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8008, 'var1': 111, 'var2': 13, 'var3': 0},
#         {'perk': 9111, 'var1': 1967, 'var2': 460, 'var3': 0},
#         {'perk': 9104, 'var1': 17, 'var2': 10, 'var3': 0},
#         {'perk': 8014, 'var1': 1163, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8139, 'var1': 1049, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 450, 'var2': 5, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 185577,
#     'physicalDamageDealtToChampions': 34423,
#     'physicalDamageTaken': 21003,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 6018,
#     'pushPings': 0,
#     'puuid': 'yzHjj7_866easD7HRZAJzQF_663UgPHo7Dr0oesjZdq0PiZvpcR7nudxVb7d43YRLT9kuNNWKJ_E5Q',
#     'quadraKills': 0,
#     'riotIdGameName': 'ARIHAN2',
#     'riotIdTagline': 'LAN',
#     'role': 'NONE',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 291,
#     'spell2Casts': 54,
#     'spell3Casts': 41,
#     'spell4Casts': 8,
#     'subteamPlacement': 0,
#     'summoner1Casts': 3,
#     'summoner1Id': 4,
#     'summoner2Casts': 2,
#     'summoner2Id': 12,
#     'summonerId': '83LZr_rH0jRwYSi7t2OVyZhpzxT3ihMI15fnLAZwj9OxTT9qyy4H0nyDGQ',
#     'summonerLevel': 59,
#     'summonerName': 'ARIHAN2',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'TOP',
#     'timeCCingOthers': 43,
#     'timePlayed': 1839,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 226583,
#     'totalDamageDealtToChampions': 45805,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 31113,
#     'totalEnemyJungleMinionsKilled': 16,
#     'totalHeal': 13374,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 179,
#     'totalTimeCCDealt': 205,
#     'totalTimeSpentDead': 215,
#     'totalUnitsHealed': 1,
#     'tripleKills': 1,
#     'trueDamageDealt': 11765,
#     'trueDamageDealtToChampions': 3958,
#     'trueDamageTaken': 838,
#     'turretKills': 4,
#     'turretTakedowns': 4,
#     'turretsLost': 3,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 13,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 2,
#     'wardsPlaced': 6,
#     'win': True},
#    {'allInPings': 2,
#     'assistMePings': 9,
#     'assists': 21,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 1,
#      'abilityUses': 331,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 70,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 1,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 1,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 340.3717339553152,
#      'damageTakenOnTeamPercentage': 0.3322502285912306,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 7,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 2,
#      'earliestBaron': 1522.9802946999998,
#      'earliestDragonTakedown': 1067.9155882,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 36,
#      'enemyJungleMonsterKills': 3,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 1,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'flawlessAces': 1,
#      'fullTeamTakedown': 0,
#      'gameLength': 1839.9090887999998,
#      'goldPerMinute': 361.89294418985213,
#      'hadOpenNexus': 0,
#      'highestWardKills': 1,
#      'immobilizeAndKillWithAlly': 8,
#      'initialBuffCount': 2,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 47.000000059604645,
#      'junglerKillsEarlyJungle': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 3.2857142857142856,
#      'killAfterHiddenWithAlly': 1,
#      'killParticipation': 0.575,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnLanersEarlyJungleAsJungler': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 14,
#      'laneMinionsFirst10Minutes': 0,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 11.000000029802322,
#      'maxKillDeficit': 5,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': -21.000000059604645,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 3152,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 14,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 12,
#      'skillshotsHit': 85,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 1,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 1,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 23,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 3,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 1,
#      'teamDamagePercentage': 0.09125820454804584,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 1,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.6320065259933472,
#      'visionScorePerMinute': 0.265376411115297,
#      'wardTakedowns': 2,
#      'wardTakedownsBefore20M': 2,
#      'wardsGuarded': 0},
#     'champExperience': 14282,
#     'champLevel': 15,
#     'championId': 20,
#     'championName': 'Nunu',
#     'championTransform': 0,
#     'commandPings': 4,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 709,
#     'damageDealtToObjectives': 23208,
#     'damageDealtToTurrets': 709,
#     'damageSelfMitigated': 26553,
#     'dangerPings': 0,
#     'deaths': 7,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 2,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 11097,
#     'goldSpent': 9185,
#     'holdPings': 0,
#     'individualPosition': 'JUNGLE',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 4645,
#     'item1': 3152,
#     'item2': 3191,
#     'item3': 1052,
#     'item4': 0,
#     'item5': 3020,
#     'item6': 3364,
#     'itemsPurchased': 15,
#     'killingSprees': 0,
#     'kills': 2,
#     'lane': 'JUNGLE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 392,
#     'magicDamageDealt': 35332,
#     'magicDamageDealtToChampions': 8507,
#     'magicDamageTaken': 4747,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 135,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 13,
#     'participantId': 2,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8230, 'var1': 13, 'var2': 0, 'var3': 0},
#         {'perk': 8275, 'var1': 21, 'var2': 0, 'var3': 0},
#         {'perk': 8234, 'var1': 10030, 'var2': 0, 'var3': 0},
#         {'perk': 8232, 'var1': 5, 'var2': 10, 'var3': 0}],
#        'style': 8200},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8126, 'var1': 586, 'var2': 0, 'var3': 0},
#         {'perk': 8105, 'var1': 13, 'var2': 5, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 34982,
#     'physicalDamageDealtToChampions': 1192,
#     'physicalDamageTaken': 36385,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 2098,
#     'pushPings': 1,
#     'puuid': 'aK3T5v83pPqbbIhH0yBAesMUK8O0UGl3NoEZWLN48tZfSkw9YqnzXFjZy8i_BJfQwVyIcWOWLJ3yZQ',
#     'quadraKills': 0,
#     'riotIdGameName': 'Luis20079',
#     'riotIdTagline': '2007',
#     'role': 'NONE',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 97,
#     'spell2Casts': 45,
#     'spell3Casts': 182,
#     'spell4Casts': 7,
#     'subteamPlacement': 0,
#     'summoner1Casts': 5,
#     'summoner1Id': 4,
#     'summoner2Casts': 16,
#     'summoner2Id': 11,
#     'summonerId': '4d7Ml5suJtpQoNemQuEhm1WrWyqQICiNzT_XBzLiXj93wqGizMyc1WOztQ',
#     'summonerLevel': 92,
#     'summonerName': 'Luis20079',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'JUNGLE',
#     'timeCCingOthers': 25,
#     'timePlayed': 1839,
#     'totalAllyJungleMinionsKilled': 110,
#     'totalDamageDealt': 193700,
#     'totalDamageDealtToChampions': 10437,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 41741,
#     'totalEnemyJungleMinionsKilled': 6,
#     'totalHeal': 24424,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 8,
#     'totalTimeCCDealt': 296,
#     'totalTimeSpentDead': 180,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 123385,
#     'trueDamageDealtToChampions': 737,
#     'trueDamageTaken': 608,
#     'turretKills': 1,
#     'turretTakedowns': 1,
#     'turretsLost': 3,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 8,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 2,
#     'wardsPlaced': 1,
#     'win': True},
#    {'allInPings': 1,
#     'assistMePings': 1,
#     'assists': 5,
#     'baitPings': 0,
#     'baronKills': 1,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 161,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 1,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 300,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 508.18418203603807,
#      'damageTakenOnTeamPercentage': 0.15529829547519292,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 3,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 1,
#      'earliestBaron': 1522.9802946999998,
#      'earliestDragonTakedown': 1067.9155882,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 9,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'flawlessAces': 1,
#      'fullTeamTakedown': 0,
#      'gameLength': 1839.9090887999998,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 421.31475112682216,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 3,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 4.333333333333333,
#      'killAfterHiddenWithAlly': 0,
#      'killParticipation': 0.325,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 1,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 1,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 17,
#      'laneMinionsFirst10Minutes': 48,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 11,
#      'maxKillDeficit': 5,
#      'maxLevelLeadLaneOpponent': 3,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 2,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 3152,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 8,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 5,
#      'skillshotsHit': 93,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 1,
#      'stealthWardsPlaced': 9,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 6,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 13,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 2,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 1,
#      'teamDamagePercentage': 0.13625096153963967,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 1,
#      'turretTakedowns': 3,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.22509777545928955,
#      'visionScorePerMinute': 0.5116327185044605,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 14774,
#     'champLevel': 16,
#     'championId': 245,
#     'championName': 'Ekko',
#     'championTransform': 0,
#     'commandPings': 2,
#     'consumablesPurchased': 2,
#     'damageDealtToBuildings': 4297,
#     'damageDealtToObjectives': 8407,
#     'damageDealtToTurrets': 4297,
#     'damageSelfMitigated': 17977,
#     'dangerPings': 0,
#     'deaths': 3,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 2,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 5,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 3,
#     'goldEarned': 12919,
#     'goldSpent': 11700,
#     'holdPings': 0,
#     'individualPosition': 'MIDDLE',
#     'inhibitorKills': 1,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 3157,
#     'item1': 3152,
#     'item2': 3145,
#     'item3': 3020,
#     'item4': 1056,
#     'item5': 3100,
#     'item6': 3340,
#     'itemsPurchased': 18,
#     'killingSprees': 2,
#     'kills': 8,
#     'lane': 'MIDDLE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 6,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 1224,
#     'magicDamageDealt': 104113,
#     'magicDamageDealtToChampions': 12306,
#     'magicDamageTaken': 3923,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 1,
#     'neutralMinionsKilled': 4,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 5,
#     'participantId': 3,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5003, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8369, 'var1': 661, 'var2': 805, 'var3': 0},
#         {'perk': 8304, 'var1': 12, 'var2': 0, 'var3': 0},
#         {'perk': 8316, 'var1': 2104, 'var2': 0, 'var3': 0},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8233, 'var1': 17, 'var2': 30, 'var3': 0},
#         {'perk': 8236, 'var1': 48, 'var2': 0, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 19220,
#     'physicalDamageDealtToChampions': 2105,
#     'physicalDamageTaken': 15120,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 6298,
#     'pushPings': 0,
#     'puuid': 'bulof2FC0QvUjYVeUiM4vbXtL248d5C1OquqogaU993lCjCAWo5u8E_GFljnyyP0nl5-85X1Q5nZ9g',
#     'quadraKills': 0,
#     'riotIdGameName': 'thelivingdead247',
#     'riotIdTagline': 'LAN',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 91,
#     'spell2Casts': 21,
#     'spell3Casts': 45,
#     'spell4Casts': 4,
#     'subteamPlacement': 0,
#     'summoner1Casts': 2,
#     'summoner1Id': 4,
#     'summoner2Casts': 2,
#     'summoner2Id': 14,
#     'summonerId': 'gh9J_UpRFd-_QpswNu3PTMzh9oDdLeBiR0DO4zXTkMS8u-4',
#     'summonerLevel': 420,
#     'summonerName': 'thelivingdead247',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'MIDDLE',
#     'timeCCingOthers': 24,
#     'timePlayed': 1839,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 127604,
#     'totalDamageDealtToChampions': 15583,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 19510,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 3662,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 162,
#     'totalTimeCCDealt': 280,
#     'totalTimeSpentDead': 102,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 4270,
#     'trueDamageDealtToChampions': 1171,
#     'trueDamageTaken': 467,
#     'turretKills': 2,
#     'turretTakedowns': 3,
#     'turretsLost': 3,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 15,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 9,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 8,
#     'assists': 12,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 11,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 413,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 1,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 300,
#      'buffsStolen': 2,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 1175.6740441919385,
#      'damageTakenOnTeamPercentage': 0.12630062796040423,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 2,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 3,
#      'earliestBaron': 1522.9802946999998,
#      'earliestDragonTakedown': 1067.9155882,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 580.9540405273438,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 2,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'fastestLegendary': 1567.5915105,
#      'firstTurretKilled': 0,
#      'flawlessAces': 1,
#      'fullTeamTakedown': 0,
#      'gameLength': 1839.9090887999998,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 473.6063017281075,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 12,
#      'killAfterHiddenWithAlly': 4,
#      'killParticipation': 0.6,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 1,
#      'killsNearEnemyTurret': 3,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 9,
#      'laneMinionsFirst10Minutes': 49,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 1,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 23,
#      'maxKillDeficit': 5,
#      'maxLevelLeadLaneOpponent': 2,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 2,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6691,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 1,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 15,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 1,
#      'shortestTimeToAceFromFirstTakedown': 23.48775909999995,
#      'skillshotsDodged': 5,
#      'skillshotsHit': 127,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 2,
#      'stealthWardsPlaced': 10,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 10,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 24,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 1,
#      'takedownsFirstXMinutes': 4,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 1,
#      'teamDamagePercentage': 0.3152139020474052,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 2,
#      'turretTakedowns': 5,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.0322192907333374,
#      'visionScorePerMinute': 0.5942144419109433,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 15142,
#     'champLevel': 16,
#     'championId': 81,
#     'championName': 'Ezreal',
#     'championTransform': 0,
#     'commandPings': 4,
#     'consumablesPurchased': 1,
#     'damageDealtToBuildings': 4882,
#     'damageDealtToObjectives': 20550,
#     'damageDealtToTurrets': 4882,
#     'damageSelfMitigated': 8367,
#     'dangerPings': 0,
#     'deaths': 2,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 2,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 5,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': True,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 14523,
#     'goldSpent': 12600,
#     'holdPings': 0,
#     'individualPosition': 'BOTTOM',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 6691,
#     'item1': 3508,
#     'item2': 3158,
#     'item3': 3042,
#     'item4': 3133,
#     'item5': 3035,
#     'item6': 3340,
#     'itemsPurchased': 17,
#     'killingSprees': 1,
#     'kills': 12,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 626,
#     'largestKillingSpree': 11,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 1192,
#     'magicDamageDealt': 20977,
#     'magicDamageDealtToChampions': 10822,
#     'magicDamageTaken': 3624,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 12,
#     'nexusKills': 1,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 11,
#     'participantId': 4,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8005, 'var1': 1163, 'var2': 728, 'var3': 435},
#         {'perk': 8009, 'var1': 2711, 'var2': 0, 'var3': 0},
#         {'perk': 9103, 'var1': 23, 'var2': 10, 'var3': 0},
#         {'perk': 8014, 'var1': 755, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8304, 'var1': 10, 'var2': 3, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 134851,
#     'physicalDamageDealtToChampions': 24350,
#     'physicalDamageTaken': 12073,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 6297,
#     'pushPings': 0,
#     'puuid': 'fC-3lKvs5r77swYG_qolaArnr9rba2fdVrDXTn6SuIm0FSVOgxGazPPHyOx3ceVOQyyNosykqKSXYg',
#     'quadraKills': 0,
#     'riotIdGameName': 'Murziny',
#     'riotIdTagline': 'CUB',
#     'role': 'CARRY',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 287,
#     'spell2Casts': 66,
#     'spell3Casts': 48,
#     'spell4Casts': 12,
#     'subteamPlacement': 0,
#     'summoner1Casts': 5,
#     'summoner1Id': 4,
#     'summoner2Casts': 6,
#     'summoner2Id': 7,
#     'summonerId': 'cUTrS3n71IEH7YEZ0dsc9WOEdh5TZ05RkmNiKCI7Ko5GKtR4NB5zk7I3QQ',
#     'summonerLevel': 194,
#     'summonerName': 'AsTh4Rat',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'BOTTOM',
#     'timeCCingOthers': 5,
#     'timePlayed': 1839,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 161833,
#     'totalDamageDealtToChampions': 36052,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 15867,
#     'totalEnemyJungleMinionsKilled': 8,
#     'totalHeal': 7165,
#     'totalHealsOnTeammates': 580,
#     'totalMinionsKilled': 170,
#     'totalTimeCCDealt': 58,
#     'totalTimeSpentDead': 20,
#     'totalUnitsHealed': 3,
#     'tripleKills': 0,
#     'trueDamageDealt': 6004,
#     'trueDamageDealtToChampions': 879,
#     'trueDamageTaken': 170,
#     'turretKills': 2,
#     'turretTakedowns': 5,
#     'turretsLost': 3,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 18,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 10,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 10,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 118,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 1,
#      'damagePerMinute': 211.79198495129205,
#      'damageTakenOnTeamPercentage': 0.13849571777623088,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 8,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 1,
#      'earliestBaron': 1522.9802946999998,
#      'earliestDragonTakedown': 1411.9031631,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 264.8377685546875,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 43,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'flawlessAces': 1,
#      'fullTeamTakedown': 0,
#      'gameLength': 1839.9090887999998,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 257.67373133831495,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 5,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 1.375,
#      'killAfterHiddenWithAlly': 1,
#      'killParticipation': 0.275,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 1,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 6,
#      'laneMinionsFirst10Minutes': 9,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 11,
#      'maxKillDeficit': 5,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6665,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 9,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 23.48775909999995,
#      'skillshotsDodged': 2,
#      'skillshotsHit': 21,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 17,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 11,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 1,
#      'takedownsFirstXMinutes': 4,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 1,
#      'teamDamagePercentage': 0.05678425778698488,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 1,
#      'turretTakedowns': 1,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.14470434188842773,
#      'visionScorePerMinute': 0.9386054509233924,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 10576,
#     'champLevel': 13,
#     'championId': 32,
#     'championName': 'Amumu',
#     'championTransform': 0,
#     'commandPings': 4,
#     'consumablesPurchased': 3,
#     'damageDealtToBuildings': 593,
#     'damageDealtToObjectives': 1207,
#     'damageDealtToTurrets': 593,
#     'damageSelfMitigated': 16553,
#     'dangerPings': 0,
#     'deaths': 8,
#     'detectorWardsPlaced': 1,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': True,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 7901,
#     'goldSpent': 7575,
#     'holdPings': 0,
#     'individualPosition': 'UTILITY',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 3859,
#     'item1': 3047,
#     'item2': 6665,
#     'item3': 3075,
#     'item4': 0,
#     'item5': 0,
#     'item6': 3340,
#     'itemsPurchased': 16,
#     'killingSprees': 0,
#     'kills': 1,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 4,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 577,
#     'magicDamageDealt': 21183,
#     'magicDamageDealtToChampions': 4665,
#     'magicDamageTaken': 4076,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 5,
#     'participantId': 5,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8439, 'var1': 519, 'var2': 788, 'var3': 0},
#         {'perk': 8463, 'var1': 596, 'var2': 0, 'var3': 0},
#         {'perk': 8473, 'var1': 426, 'var2': 0, 'var3': 0},
#         {'perk': 8242, 'var1': 69, 'var2': 0, 'var3': 0}],
#        'style': 8400},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8126, 'var1': 424, 'var2': 0, 'var3': 0},
#         {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 5660,
#     'physicalDamageDealtToChampions': 985,
#     'physicalDamageTaken': 12325,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 1392,
#     'pushPings': 0,
#     'puuid': 'JYPXADV1Xhnlq9y0BA4A2vTOBotFpLJP1qQW6Mt_2uVO9NXruJ7ATkZWhS52ateRHjZqn_P_3pznXw',
#     'quadraKills': 0,
#     'riotIdGameName': 'PouMorenito36',
#     'riotIdTagline': 'LAN',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 45,
#     'spell2Casts': 34,
#     'spell3Casts': 32,
#     'spell4Casts': 7,
#     'subteamPlacement': 0,
#     'summoner1Casts': 5,
#     'summoner1Id': 3,
#     'summoner2Casts': 4,
#     'summoner2Id': 4,
#     'summonerId': 'yie3_bPCulmq_xfBUWIb_evXr8xB6zP3sGbsz5TVPUZKiHkEfoo3-ysffg',
#     'summonerLevel': 59,
#     'summonerName': 'PouMorenito36',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'UTILITY',
#     'timeCCingOthers': 34,
#     'timePlayed': 1839,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 32081,
#     'totalDamageDealtToChampions': 6494,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 17399,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 1272,
#     'totalHealsOnTeammates': 264,
#     'totalMinionsKilled': 37,
#     'totalTimeCCDealt': 87,
#     'totalTimeSpentDead': 211,
#     'totalUnitsHealed': 5,
#     'tripleKills': 0,
#     'trueDamageDealt': 5237,
#     'trueDamageDealtToChampions': 843,
#     'trueDamageTaken': 998,
#     'turretKills': 1,
#     'turretTakedowns': 1,
#     'turretsLost': 3,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 28,
#     'visionWardsBoughtInGame': 1,
#     'wardsKilled': 0,
#     'wardsPlaced': 18,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 5,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 184,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 300,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.6066643838517027,
#      'controlWardsPlaced': 1,
#      'damagePerMinute': 421.37777436637015,
#      'damageTakenOnTeamPercentage': 0.24245831887488734,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 9,
#      'dodgeSkillShotsSmallWindow': 1,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 11,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 784.5315666,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 1,
#      'gameLength': 1839.9090887999998,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 274.22949689273804,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 2,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 4,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 0.8888888888888888,
#      'killAfterHiddenWithAlly': 1,
#      'killParticipation': 0.3076923076923077,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 1,
#      'knockEnemyIntoTeamAndKill': 2,
#      'landSkillShotsEarlyGame': 0,
#      'laneMinionsFirst10Minutes': 34,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 4,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6665,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 8,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 2,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
# ...
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 1,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 10,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 14,
#      'skillshotsHit': 6,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 9,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 11,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 5,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.1848380189729703,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 2,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 1,
#      'turretsTakenWithRiftHerald': 5,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.031213581562042236,
#      'visionScorePerMinute': 0.5756668820438052,
#      'wardTakedowns': 1,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 12089,
#     'champLevel': 14,
#     'championId': 202,
#     'championName': 'Jhin',
#     'championTransform': 0,
#     'commandPings': 8,
#     'consumablesPurchased': 9,
#     'damageDealtToBuildings': 2068,
#     'damageDealtToObjectives': 6554,
#     'damageDealtToTurrets': 2068,
#     'damageSelfMitigated': 12199,
#     'dangerPings': 0,
#     'deaths': 8,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 1,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 1,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 6,
#     'goldEarned': 10681,
#     'goldSpent': 9250,
#     'holdPings': 0,
#     'individualPosition': 'BOTTOM',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 3095,
#     'item1': 2003,
#     'item2': 3087,
#     'item3': 3009,
#     'item4': 1038,
#     'item5': 1018,
#     'item6': 3340,
#     'itemsPurchased': 21,
#     'killingSprees': 2,
#     'kills': 6,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 1237,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 682,
#     'magicDamageDealt': 10789,
#     'magicDamageDealtToChampions': 2418,
#     'magicDamageTaken': 7199,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 4,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 1,
#     'participantId': 9,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8128, 'var1': 636, 'var2': 13, 'var3': 0},
#         {'perk': 8139, 'var1': 958, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 18, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 450, 'var2': 5, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8014, 'var1': 329, 'var2': 0, 'var3': 0},
#         {'perk': 8009, 'var1': 1300, 'var2': 0, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 106755,
#     'physicalDamageDealtToChampions': 13355,
#     'physicalDamageTaken': 14587,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 3015,
#     'pushPings': 0,
#     'puuid': 'K27ooTlTnYuVRk-y8MUScFRui7P9tYN0GPoFMVJbOvGx_u-VmPyQO8RrZYTfH2Op-0h1Mej0VhEyVw',
#     'quadraKills': 0,
#     'riotIdGameName': 'rovert79',
#     'riotIdTagline': 'LAN',
#     'role': 'CARRY',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 61,
#     'spell2Casts': 26,
#     'spell3Casts': 19,
#     'spell4Casts': 19,
#     'subteamPlacement': 0,
#     'summoner1Casts': 6,
#     'summoner1Id': 7,
#     'summoner2Casts': 4,
#     'summoner2Id': 4,
#     'summonerId': 'nOFe8z4WiXi4wseXk3w5eAfZ2gH8X1CnOldltkDDRIggRU8',
#     'summonerLevel': 68,
#     'summonerName': 'rovert79',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'BOTTOM',
#     'timeCCingOthers': 23,
#     'timePlayed': 1839,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 117545,
#     'totalDamageDealtToChampions': 15774,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 22112,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 3536,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 167,
#     'totalTimeCCDealt': 70,
#     'totalTimeSpentDead': 235,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 0,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 325,
#     'turretKills': 0,
#     'turretTakedowns': 1,
#     'turretsLost': 10,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 17,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 1,
#     'wardsPlaced': 9,
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 13,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 99,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.6799686049249108,
#      'controlWardsPlaced': 3,
#      'damagePerMinute': 292.8162253529491,
#      'damageTakenOnTeamPercentage': 0.19517015400819637,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 8,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 545.9683227539062,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 91,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'fasterSupportQuestCompletion': 1,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 784.5315666,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 1,
#      'gameLength': 1839.9090887999998,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 250.49049917696678,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 7,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 1.875,
#      'killAfterHiddenWithAlly': 1,
#      'killParticipation': 0.5769230769230769,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 6,
#      'landSkillShotsEarlyGame': 3,
#      'laneMinionsFirst10Minutes': 13,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 7,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 3190,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 13,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 22,
#      'skillshotsHit': 16,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 1,
#      'stealthWardsPlaced': 13,
#      'survivedSingleDigitHpCount': 1,
#      'survivedThreeImmobilizesInFight': 6,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 15,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 9,
#      'takedownsInAlcove': 1,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.10521353840207827,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 2,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 1,
#      'turretsTakenWithRiftHerald': 5,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.16918635368347168,
#      'visionScorePerMinute': 1.0974046731136082,
#      'wardTakedowns': 1,
#      'wardTakedownsBefore20M': 1,
#      'wardsGuarded': 1},
#     'champExperience': 9632,
#     'champLevel': 12,
#     'championId': 111,
#     'championName': 'Nautilus',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 5,
#     'damageDealtToBuildings': 318,
#     'damageDealtToObjectives': 539,
#     'damageDealtToTurrets': 318,
#     'damageSelfMitigated': 41645,
#     'dangerPings': 0,
#     'deaths': 8,
#     'detectorWardsPlaced': 3,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 1,
#     'goldEarned': 7681,
#     'goldSpent': 7775,
#     'holdPings': 0,
#     'individualPosition': 'UTILITY',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 3860,
#     'item1': 2031,
#     'item2': 3190,
#     'item3': 3111,
#     'item4': 3075,
#     'item5': 0,
#     'item6': 3340,
#     'itemsPurchased': 18,
#     'killingSprees': 1,
#     'kills': 2,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 23,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 634,
#     'magicDamageDealt': 12046,
#     'magicDamageDealtToChampions': 5891,
#     'magicDamageTaken': 9989,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 2,
#     'participantId': 10,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5002, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8439, 'var1': 1128, 'var2': 1590, 'var3': 0},
#         {'perk': 8401, 'var1': 316, 'var2': 0, 'var3': 0},
#         {'perk': 8429, 'var1': 60, 'var2': 14, 'var3': 12},
#         {'perk': 8453, 'var1': 389, 'var2': 951, 'var3': 0}],
#        'style': 8400},
#       {'description': 'subStyle',
#        'selections': [{'perk': 9105, 'var1': 19, 'var2': 10, 'var3': 0},
#         {'perk': 9111, 'var1': 1038, 'var2': 300, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 5737,
#     'physicalDamageDealtToChampions': 2463,
#     'physicalDamageTaken': 15534,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 6316,
#     'pushPings': 0,
#     'puuid': '-4L801fRUAH_n6nUxYhH3K3-uTDCdZRWUxKv0IQzmj1rotZkGHP6sLcYIPTfwxGWYcfRY4JdObhowQ',
#     'quadraKills': 0,
#     'riotIdGameName': 'pequeñanay',
#     'riotIdTagline': '1711',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 31,
#     'spell2Casts': 29,
#     'spell3Casts': 30,
#     'spell4Casts': 9,
#     'subteamPlacement': 0,
#     'summoner1Casts': 6,
#     'summoner1Id': 14,
#     'summoner2Casts': 5,
#     'summoner2Id': 4,
#     'summonerId': 'OJj0E3OagJuwqXJiXKVNc40l_c0nB6JlxGWFciD2T81tKts',
#     'summonerLevel': 386,
#     'summonerName': 'DOGBONDMAN',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'UTILITY',
#     'timeCCingOthers': 52,
#     'timePlayed': 1839,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 21222,
#     'totalDamageDealtToChampions': 8979,
#     'totalDamageShieldedOnTeammates': 545,
#     'totalDamageTaken': 27094,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 3381,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 26,
#     'totalTimeCCDealt': 245,
#     'totalTimeSpentDead': 195,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 3438,
#     'trueDamageDealtToChampions': 624,
#     'trueDamageTaken': 1569,
#     'turretKills': 1,
#     'turretTakedowns': 1,
#     'turretsLost': 10,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 33,
#     'visionWardsBoughtInGame': 3,
#     'wardsKilled': 1,
#     'wardsPlaced': 16,
#     'win': False}],
#   'platformId': 'LA1',
#   'queueId': 420,
#   'teams': [{'bans': [{'championId': 33, 'pickTurn': 1},
#      {'championId': 875, 'pickTurn': 2},
#      {'championId': 63, 'pickTurn': 3},
#      {'championId': 895, 'pickTurn': 4},
#      {'championId': 45, 'pickTurn': 5}],
#     'objectives': {'baron': {'first': True, 'kills': 1},
#      'champion': {'first': True, 'kills': 40},
#      'dragon': {'first': False, 'kills': 3},
#      'horde': {'first': False, 'kills': 0},
#      'inhibitor': {'first': True, 'kills': 1},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': False, 'kills': 10}},
#     'teamId': 100,
#     'win': True},
#    {'bans': [{'championId': 74, 'pickTurn': 6},
#      {'championId': 63, 'pickTurn': 7},
#      {'championId': 145, 'pickTurn': 8},
#      {'championId': 84, 'pickTurn': 9},
#      {'championId': 23, 'pickTurn': 10}],
#     'objectives': {'baron': {'first': False, 'kills': 0},
#      'champion': {'first': False, 'kills': 26},
#      'dragon': {'first': True, 'kills': 1},
#      'horde': {'first': False, 'kills': 0},
#      'inhibitor': {'first': False, 'kills': 0},
#      'riftHerald': {'first': True, 'kills': 2},
#      'tower': {'first': True, 'kills': 3}},
#     'teamId': 200,
#     'win': False}],
#   'tournamentCode': ''}}

# %% [markdown]
# That's a lot of data!
# Let's break it down

# %%
# the two headline sections of the data
match_data.keys()
# Out:
# dict_keys(['metadata', 'info'])

# %%
# "metadata" contains the puuid for every player in the game
match_data['metadata']

# NOTE: The order in which these puuid's appear in this the "participants" list
# is the same order they will appear for data elsewhere in this dictionary (useful for later)
# Out:
# {'dataVersion': '2',
#  'matchId': 'LA1_1459873188',
#  'participants': ['yzHjj7_866easD7HRZAJzQF_663UgPHo7Dr0oesjZdq0PiZvpcR7nudxVb7d43YRLT9kuNNWKJ_E5Q',
#   'aK3T5v83pPqbbIhH0yBAesMUK8O0UGl3NoEZWLN48tZfSkw9YqnzXFjZy8i_BJfQwVyIcWOWLJ3yZQ',
#   'bulof2FC0QvUjYVeUiM4vbXtL248d5C1OquqogaU993lCjCAWo5u8E_GFljnyyP0nl5-85X1Q5nZ9g',
#   'fC-3lKvs5r77swYG_qolaArnr9rba2fdVrDXTn6SuIm0FSVOgxGazPPHyOx3ceVOQyyNosykqKSXYg',
#   'JYPXADV1Xhnlq9y0BA4A2vTOBotFpLJP1qQW6Mt_2uVO9NXruJ7ATkZWhS52ateRHjZqn_P_3pznXw',
#   'ug6gjzUWzBgSY9Q2M4whHHKo_oyCatFoIuhcJHWwW6whTGrSutmObCCdtLGDqihAp5xaE7QlTAXuoQ',
#   '3GgmyGhFZN1ViTEot9NYaeNXQyMVdESpfYcpngXQFyRJv45wO5Lpo3IXLxcwRJtKmJqgzvFCtdo5vA',
#   'fDbSKld9q7WtYR8UJ_Emkuwg-ec17ZGndX-hfIjE9tbSNs-88Rwg4mYMQEdFFsmPLa6vub81HtKjvA',
#   'K27ooTlTnYuVRk-y8MUScFRui7P9tYN0GPoFMVJbOvGx_u-VmPyQO8RrZYTfH2Op-0h1Mej0VhEyVw',
#   '-4L801fRUAH_n6nUxYhH3K3-uTDCdZRWUxKv0IQzmj1rotZkGHP6sLcYIPTfwxGWYcfRY4JdObhowQ']}

# %%
# "info" contains lots of data about the game, like when it was created, how long it lasted etc...
match_data['info'].keys()
# Out:
# dict_keys(['gameCreation', 'gameDuration', 'gameEndTimestamp', 'gameId', 'gameMode', 'gameName', 'gameStartTimestamp', 'gameType', 'gameVersion', 'mapId', 'participants', 'platformId', 'queueId', 'teams', 'tournamentCode'])

# %%
# For instance, this is how long the game lasted:
match_data['info']['gameDuration'] / 60 # / 60 to get it into minutes
# Out:
# 30.65

# %%
# Within info, participants contains a list of length 10, each with further information about the player
len(match_data['info']['participants'])
# Out:
# 10

# %%
# To save time, we'll assign a variable for first player
player_data = match_data['info']['participants'][0]
player_data
# Out:
# {'allInPings': 0,
#  'assistMePings': 0,
#  'assists': 6,
#  'baitPings': 0,
#  'baronKills': 0,
#  'basicPings': 0,
#  'bountyLevel': 4,
#  'challenges': {'12AssistStreakCount': 0,
#   'abilityUses': 394,
#   'acesBefore15Minutes': 0,
#   'alliedJungleMonsterKills': 0,
#   'baronBuffGoldAdvantageOverThreshold': 1,
#   'baronTakedowns': 1,
#   'blastConeOppositeOpponentCount': 0,
#   'bountyGold': 0,
#   'buffsStolen': 0,
#   'completeSupportQuestInTime': 0,
#   'controlWardsPlaced': 0,
#   'damagePerMinute': 1493.7438949999932,
#   'damageTakenOnTeamPercentage': 0.2476551301969414,
#   'dancedWithRiftHerald': 0,
#   'deathsByEnemyChamps': 6,
#   'dodgeSkillShotsSmallWindow': 0,
#   'doubleAces': 0,
#   'dragonTakedowns': 1,
#   'earliestBaron': 1522.9802946999998,
#   'earliestDragonTakedown': 1411.9031631,
#   'earlyLaningPhaseGoldExpAdvantage': 1,
#   'effectiveHealAndShielding': 0,
#   'elderDragonKillsWithOpposingSoul': 0,
#   'elderDragonMultikills': 0,
#   'enemyChampionImmobilizations': 57,
#   'enemyJungleMonsterKills': 12,
#   'epicMonsterKillsNearEnemyJungler': 0,
#   'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#   'epicMonsterSteals': 0,
#   'epicMonsterStolenWithoutSmite': 0,
#   'firstTurretKilled': 0,
#   'flawlessAces': 1,
#   'fullTeamTakedown': 0,
#   'gameLength': 1839.9090887999998,
#   'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#   'goldPerMinute': 546.6127536189495,
#   'hadOpenNexus': 0,
#   'highestChampionDamage': 1,
#   'highestWardKills': 1,
#   'immobilizeAndKillWithAlly': 7,
#   'initialBuffCount': 0,
#   'initialCrabCount': 0,
#   'jungleCsBefore10Minutes': 0,
#   'junglerTakedownsNearDamagedEpicMonster': 2,
#   'kTurretsDestroyedBeforePlatesFall': 1,
#   'kda': 3.8333333333333335,
#   'killAfterHiddenWithAlly': 2,
#   'killParticipation': 0.575,
#   'killedChampTookFullTeamDamageSurvived': 0,
#   'killingSprees': 3,
#   'killsNearEnemyTurret': 4,
#   'killsOnOtherLanesEarlyJungleAsLaner': 0,
#   'killsOnRecentlyHealedByAramPack': 0,
#   'killsUnderOwnTurret': 1,
#   'killsWithHelpFromEpicMonster': 0,
#   'knockEnemyIntoTeamAndKill': 0,
#   'landSkillShotsEarlyGame': 7,
#   'laneMinionsFirst10Minutes': 53,
#   'laningPhaseGoldExpAdvantage': 1,
#   'legendaryCount': 0,
#   'lostAnInhibitor': 0,
#   'maxCsAdvantageOnLaneOpponent': 102.2000000178814,
#   'maxKillDeficit': 5,
#   'maxLevelLeadLaneOpponent': 3,
#   'mejaisFullStackInTime': 0,
#   'moreEnemyJungleThanOpponent': 0,
#   'multiKillOneSpell': 0,
#   'multiTurretRiftHeraldCount': 0,
#   'multikills': 5,
#   'multikillsAfterAggressiveFlash': 0,
#   'mythicItemUsed': 3031,
#   'outerTurretExecutesBefore10Minutes': 0,
#   'outnumberedKills': 4,
#   'outnumberedNexusKill': 0,
#   'perfectDragonSoulsTaken': 0,
#   'perfectGame': 0,
#   'pickKillWithAlly': 12,
#   'playedChampSelectPosition': 1,
#   'poroExplosions': 0,
#   'quickCleanse': 0,
#   'quickFirstTurret': 0,
#   'quickSoloKills': 0,
#   'riftHeraldTakedowns': 0,
#   'saveAllyFromDeath': 0,
#   'scuttleCrabKills': 1,
#   'shortestTimeToAceFromFirstTakedown': 23.48775909999995,
#   'skillshotsDodged': 14,
#   'skillshotsHit': 28,
#   'snowballsHit': 0,
#   'soloBaronKills': 0,
#   'soloKills': 6,
#   'stealthWardsPlaced': 6,
#   'survivedSingleDigitHpCount': 0,
#   'survivedThreeImmobilizesInFight': 2,
#   'takedownOnFirstTurret': 0,
#   'takedowns': 23,
#   'takedownsAfterGainingLevelAdvantage': 0,
#   'takedownsBeforeJungleMinionSpawn': 0,
#   'takedownsFirstXMinutes': 2,
#   'takedownsInAlcove': 0,
#   'takedownsInEnemyFountain': 0,
#   'teamBaronKills': 1,
#   'teamDamagePercentage': 0.40049267407792444,
#   'teamElderDragonKills': 0,
#   'teamRiftHeraldKills': 0,
#   'tookLargeDamageSurvived': 0,
#   'turretPlatesTaken': 5,
#   'turretTakedowns': 4,
#   'turretsTakenWithRiftHerald': 0,
#   'twentyMinionsIn3SecondsCount': 0,
#   'twoWardsOneSweeperCount': 0,
#   'unseenRecalls': 0,
#   'visionScoreAdvantageLaneOpponent': -0.5244678258895874,
#   'visionScorePerMinute': 0.42809642360378936,
#   'wardTakedowns': 2,
#   'wardTakedownsBefore20M': 2,
#   'wardsGuarded': 0},
#  'champExperience': 17538,
#  'champLevel': 17,
#  'championId': 777,
#  'championName': 'Yone',
#  'championTransform': 0,
#  'commandPings': 5,
#  'consumablesPurchased': 1,
#  'damageDealtToBuildings': 6804,
#  'damageDealtToObjectives': 26475,
#  'damageDealtToTurrets': 6804,
#  'damageSelfMitigated': 30379,
#  'dangerPings': 0,
#  'deaths': 6,
#  'detectorWardsPlaced': 0,
#  'doubleKills': 4,
#  'dragonKills': 1,
#  'eligibleForProgression': True,
#  'enemyMissingPings': 10,
#  'enemyVisionPings': 1,
#  'firstBloodAssist': False,
#  'firstBloodKill': False,
#  'firstTowerAssist': False,
#  'firstTowerKill': False,
#  'gameEndedInEarlySurrender': False,
#  'gameEndedInSurrender': False,
#  'getBackPings': 2,
#  'goldEarned': 16761,
#  'goldSpent': 14300,
#  'holdPings': 0,
#  'individualPosition': 'TOP',
#  'inhibitorKills': 0,
#  'inhibitorTakedowns': 0,
#  'inhibitorsLost': 0,
#  'item0': 3031,
#  'item1': 3153,
#  'item2': 3006,
#  'item3': 6673,
#  'item4': 6672,
#  'item5': 1055,
#  'item6': 3340,
#  'itemsPurchased': 23,
#  'killingSprees': 4,
#  'kills': 17,
#  'lane': 'JUNGLE',
#  'largestCriticalStrike': 3339,
#  'largestKillingSpree': 6,
#  'largestMultiKill': 3,
#  'longestTimeSpentLiving': 463,
#  'magicDamageDealt': 29239,
#  'magicDamageDealtToChampions': 7423,
#  'magicDamageTaken': 9271,
#  'missions': {'playerScore0': 0,
#   'playerScore1': 0,
#   'playerScore10': 0,
#   'playerScore11': 0,
#   'playerScore2': 0,
#   'playerScore3': 0,
#   'playerScore4': 0,
#   'playerScore5': 0,
#   'playerScore6': 0,
#   'playerScore7': 0,
#   'playerScore8': 0,
#   'playerScore9': 0},
#  'needVisionPings': 0,
#  'neutralMinionsKilled': 27,
#  'nexusKills': 0,
#  'nexusLost': 0,
#  'nexusTakedowns': 0,
#  'objectivesStolen': 0,
#  'objectivesStolenAssists': 0,
#  'onMyWayPings': 5,
#  'participantId': 1,
#  'pentaKills': 0,
#  'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#   'styles': [{'description': 'primaryStyle',
#     'selections': [{'perk': 8008, 'var1': 111, 'var2': 13, 'var3': 0},
#      {'perk': 9111, 'var1': 1967, 'var2': 460, 'var3': 0},
#      {'perk': 9104, 'var1': 17, 'var2': 10, 'var3': 0},
#      {'perk': 8014, 'var1': 1163, 'var2': 0, 'var3': 0}],
#     'style': 8000},
#    {'description': 'subStyle',
#     'selections': [{'perk': 8139, 'var1': 1049, 'var2': 0, 'var3': 0},
#      {'perk': 8135, 'var1': 450, 'var2': 5, 'var3': 0}],
#     'style': 8100}]},
#  'physicalDamageDealt': 185577,
#  'physicalDamageDealtToChampions': 34423,
#  'physicalDamageTaken': 21003,
#  'placement': 0,
#  'playerAugment1': 0,
#  'playerAugment2': 0,
#  'playerAugment3': 0,
#  'playerAugment4': 0,
#  'playerScore0': 0,
#  'playerScore1': 0,
#  'playerScore10': 0,
#  'playerScore11': 0,
#  'playerScore2': 0,
#  'playerScore3': 0,
#  'playerScore4': 0,
#  'playerScore5': 0,
#  'playerScore6': 0,
#  'playerScore7': 0,
#  'playerScore8': 0,
#  'playerScore9': 0,
#  'playerSubteamId': 0,
#  'profileIcon': 6018,
#  'pushPings': 0,
#  'puuid': 'yzHjj7_866easD7HRZAJzQF_663UgPHo7Dr0oesjZdq0PiZvpcR7nudxVb7d43YRLT9kuNNWKJ_E5Q',
#  'quadraKills': 0,
#  'riotIdGameName': 'ARIHAN2',
#  'riotIdTagline': 'LAN',
#  'role': 'NONE',
#  'sightWardsBoughtInGame': 0,
#  'spell1Casts': 291,
#  'spell2Casts': 54,
#  'spell3Casts': 41,
#  'spell4Casts': 8,
#  'subteamPlacement': 0,
#  'summoner1Casts': 3,
#  'summoner1Id': 4,
#  'summoner2Casts': 2,
#  'summoner2Id': 12,
#  'summonerId': '83LZr_rH0jRwYSi7t2OVyZhpzxT3ihMI15fnLAZwj9OxTT9qyy4H0nyDGQ',
#  'summonerLevel': 59,
#  'summonerName': 'ARIHAN2',
#  'teamEarlySurrendered': False,
#  'teamId': 100,
#  'teamPosition': 'TOP',
#  'timeCCingOthers': 43,
#  'timePlayed': 1839,
#  'totalAllyJungleMinionsKilled': 0,
#  'totalDamageDealt': 226583,
#  'totalDamageDealtToChampions': 45805,
#  'totalDamageShieldedOnTeammates': 0,
#  'totalDamageTaken': 31113,
#  'totalEnemyJungleMinionsKilled': 16,
#  'totalHeal': 13374,
#  'totalHealsOnTeammates': 0,
#  'totalMinionsKilled': 179,
#  'totalTimeCCDealt': 205,
#  'totalTimeSpentDead': 215,
#  'totalUnitsHealed': 1,
#  'tripleKills': 1,
#  'trueDamageDealt': 11765,
#  'trueDamageDealtToChampions': 3958,
#  'trueDamageTaken': 838,
#  'turretKills': 4,
#  'turretTakedowns': 4,
#  'turretsLost': 3,
#  'unrealKills': 0,
#  'visionClearedPings': 0,
#  'visionScore': 13,
#  'visionWardsBoughtInGame': 0,
#  'wardsKilled': 2,
#  'wardsPlaced': 6,
#  'win': True}

# %%
# Then, we can find out information about them in the game, like which Champion they're playing...
player_data['championName']
# Out:
# 'Yone'

# %%
# Maybe their KDA?
k = player_data['kills']
d = player_data['deaths']
a = player_data['assists']
print("Kills:", k)
print("Deaths:", d)
print("Assists:", a)
print("KDA:", (k + a) / d)
# Out:
# Kills: 17
# Deaths: 6
# Assists: 6
# KDA: 3.8333333333333335

# %%
# or their role?
player_data['teamPosition']
# Out:
# 'TOP'

# %% [markdown]
# However we don't want the information about any random player in that game! \
# We want to get information about the player we were searching for originally, so we need to find out where they are
#
# To do this, we grab the list of all the participants puuids and then we use "index" to find out where our player is

# %%
# A list of all the participants puuids
participants = match_data['metadata']['participants']
# Now, find where in the data our players puuid is found
player_index = participants.index(puuid)
player_index
# Out:
# 5

# %%
# This should match the puuid we used to search for the match IDs, go back up and check
participants[player_index]
# Out:
# 'ug6gjzUWzBgSY9Q2M4whHHKo_oyCatFoIuhcJHWwW6whTGrSutmObCCdtLGDqihAp5xaE7QlTAXuoQ'

# %% [markdown]
# Let's check it works by using this index to get the players name from the data

# %%
# Hopefully the name below is what you inputted into the first function!
match_data['info']['participants'][player_index]['summonerName']
# Out:
# 'M0DEST0'

# %% [markdown]
# Now we know where our player is, we can grab their data

# %%
player_data = match_data['info']['participants'][player_index]

champ = player_data['championName']
k = player_data['kills']
d = player_data['deaths']
a = player_data['assists']
win = player_data['win']

print("Champ:", champ, "Kills:", k, "Deaths:", d, "Assists:", a, "Win:", win)
# Out:
# Champ: Mordekaiser Kills: 3 Deaths: 9 Assists: 5 Win: False

# %% [markdown]
# ### Gathering Data
#
# For whatever we're building, we may want to gather lots of data about a player \
# To make this easier, we'll build some functions
# Let's start by looking at the API calls we've already made

# %%
# The first function simply gets the puuid, given a summoner name and region
# This is exactly the same as our first example, except we're building the API URL from scratch
def get_puuid(summoner_name, region, api_key):
    api_url = (
        "https://" + 
        region +
        ".api.riotgames.com/lol/summoner/v4/summoners/by-name/" +
        summoner_name +
        "?api_key=" +
        api_key
    )
    
    print(api_url)
    
    resp = requests.get(api_url)
    player_info = resp.json()
    puuid = player_info['puuid']
    return puuid

# %%
summoner_name = 'M0DEST0'
region = 'LA1'

puuid = get_puuid(summoner_name, region, api_key)
puuid
# Out:
# https://LA1.api.riotgames.com/lol/summoner/v4/summoners/by-name/M0DEST0?api_key=RGAPI-3ee6f984-bd4e-43fe-a855-51c08b131105
# 'ug6gjzUWzBgSY9Q2M4whHHKo_oyCatFoIuhcJHWwW6whTGrSutmObCCdtLGDqihAp5xaE7QlTAXuoQ'

# %%
# The function to get a list of all the match IDs (2nd example above) given a players puuid and mass region
def get_match_ids(puuid, mass_region, api_key):
    api_url = (
        "https://" +
        mass_region +
        ".api.riotgames.com/lol/match/v5/matches/by-puuid/" +
        puuid + 
        "/ids?start=0&count=20" + 
        "&api_key=" + 
        api_key
    )
    
    print(api_url)
    
    resp = requests.get(api_url)
    match_ids = resp.json()
    return match_ids

# %%
# NOTE: region and mass_region are different
# for instance, NA1 is the North American region
# which is part of the AMERICAS mass region
# EUW1 is Europe West region, part of the EUROPE mass region
mass_region = 'AMERICAS'

match_ids = get_match_ids(puuid, mass_region, api_key)
match_ids
# Out:
# https://AMERICAS.api.riotgames.com/lol/match/v5/matches/by-puuid/ug6gjzUWzBgSY9Q2M4whHHKo_oyCatFoIuhcJHWwW6whTGrSutmObCCdtLGDqihAp5xaE7QlTAXuoQ/ids?start=0&count=20&api_key=RGAPI-3ee6f984-bd4e-43fe-a855-51c08b131105
# ['LA1_1460596933',
#  'LA1_1460572182',
#  'LA1_1460549970',
#  'LA1_1460533557',
#  'LA1_1460494945',
#  'LA1_1459873188',
#  'LA1_1459871292',
#  'LA1_1459857257',
#  'LA1_1459837219',
#  'LA1_1459699435',
#  'LA1_1459689802',
#  'LA1_1459681842',
#  'LA1_1459675534',
#  'LA1_1459662989',
#  'LA1_1459642993',
#  'LA1_1458661840',
#  'LA1_1458641722',
#  'LA1_1458622715',
#  'LA1_1458611574',
#  'LA1_1458258515']

# %%
# From a given match ID and mass region, get the data about the game
def get_match_data(match_id, mass_region, api_key):
    api_url = (
        "https://" + 
        mass_region + 
        ".api.riotgames.com/lol/match/v5/matches/" +
        match_id + 
        "?api_key=" + 
        api_key
    )
    
    resp = requests.get(api_url)
    match_data = resp.json()
    return match_data

# %%
match_id = match_ids[0]
match_data = get_match_data(match_id, mass_region, api_key)
match_data
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'LA1_1460596933',
#   'participants': ['ug6gjzUWzBgSY9Q2M4whHHKo_oyCatFoIuhcJHWwW6whTGrSutmObCCdtLGDqihAp5xaE7QlTAXuoQ',
#    '3GgmyGhFZN1ViTEot9NYaeNXQyMVdESpfYcpngXQFyRJv45wO5Lpo3IXLxcwRJtKmJqgzvFCtdo5vA',
#    'cSqaesq5mi3MGix7AdDk28PwONfU5Rlxih59EEGwA3PUrqTWVzoXw2EyNDwswKuCaaVoTYgv87B-Lw',
#    'FqWjePhOHsQ_5E9dQV0vTnl0Hlu-4DQ5T9otnFcaNOSs5AdzQ-l1oH8p1OX4KkR_5Mhr1obxC650AA',
#    'WH1hShydsycLS8AbDlbP3n1CyhLzUhJmw6-NvjtvmgKygbXBRhkmgGyHJkPNDCihOJtSpO3f5vx4wg',
#    '_knAeY3PgCMfnvEHARY8JbbdoyfRP7g3UmHmW-GH7GvzzOIqzpTLJOomvqmj186HqPSv5Zhiqi12sA',
#    'A8Gmb-TcgJsDwWUABRA3gjynDsJMBrZH-SUnbDwbXekxPpIX9eKlPxSqtXTH0k4pHG_kLS-0voiX_Q',
#    'nKZ_MfhlGOOaXkPNn3fy6V6noc_hHyKYHkQN7RgVu6V0git_7NBj9M1eH6UHofAFRJE0zriK_1fwHw',
#    'fqGjV8P6gkhsge0WKk_uXVxMW7l17-uzfm4aukMfnwBg23nJiHQEIXma0wrxw5wBSYaotD8M_WpJDQ',
#    '-c1z5kmm2qxDlHX94c3ing647J0bQmVi5aG2w57zj2eB8nWIr_Ef8s-OiHRulY7lZdZxjjclSH5ebg']},
#  'info': {'gameCreation': 1700975799006,
#   'gameDuration': 2499,
#   'gameEndTimestamp': 1700978541955,
#   'gameId': 1460596933,
#   'gameMode': 'CLASSIC',
#   'gameName': 'teambuilder-match-1460596933',
#   'gameStartTimestamp': 1700976042272,
#   'gameType': 'MATCHED_GAME',
#   'gameVersion': '13.23.544.5515',
#   'mapId': 11,
#   'participants': [{'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 9,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 150,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.6762572322932532,
#      'controlWardsPlaced': 1,
#      'damagePerMinute': 630.2564261771992,
#      'damageTakenOnTeamPercentage': 0.20753925881638197,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 12,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 8,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 969.5400808999999,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 1,
#      'gameLength': 2499.9534369,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 262.9467177582255,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 2,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 0.8333333333333334,
#      'killAfterHiddenWithAlly': 1,
#      'killParticipation': 0.3125,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 0,
#      'laneMinionsFirst10Minutes': 42,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 7,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6665,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 10,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 25,
#      'skillshotsHit': 0,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'soloTurretsLategame': 1,
#      'stealthWardsPlaced': 9,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 1,
#      'takedowns': 10,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 1,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.15299110872782412,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 3,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.3400420546531677,
#      'visionScorePerMinute': 0.4140210779411605,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 17459,
#     'champLevel': 17,
#     'championId': 106,
#     'championName': 'Volibear',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 3,
#     'damageDealtToBuildings': 4831,
#     'damageDealtToObjectives': 4831,
#     'damageDealtToTurrets': 4831,
#     'damageSelfMitigated': 55838,
#     'dangerPings': 0,
#     'deaths': 12,
#     'detectorWardsPlaced': 1,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 10955,
#     'goldSpent': 10125,
#     'holdPings': 0,
#     'individualPosition': 'TOP',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 4,
#     'item0': 1056,
#     'item1': 3115,
#     'item2': 6665,
#     'item3': 3111,
#     'item4': 3211,
#     'item5': 3067,
#     'item6': 3340,
#     'itemsPurchased': 18,
#     'killingSprees': 0,
#     'kills': 1,
#     'lane': 'JUNGLE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 552,
#     'magicDamageDealt': 111101,
#     'magicDamageDealtToChampions': 15229,
#     'magicDamageTaken': 17225,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 1,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8008, 'var1': 46, 'var2': 11, 'var3': 0},
#         {'perk': 9111, 'var1': 913, 'var2': 200, 'var3': 0},
#         {'perk': 9104, 'var1': 33, 'var2': 50, 'var3': 0},
#         {'perk': 8299, 'var1': 1143, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8446, 'var1': 916, 'var2': 0, 'var3': 0},
#         {'perk': 8453, 'var1': 814, 'var2': 404, 'var3': 0}],
#        'style': 8400}]},
#     'physicalDamageDealt': 45532,
#     'physicalDamageDealtToChampions': 8428,
#     'physicalDamageTaken': 27523,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 5497,
#     'pushPings': 0,
#     'puuid': 'ug6gjzUWzBgSY9Q2M4whHHKo_oyCatFoIuhcJHWwW6whTGrSutmObCCdtLGDqihAp5xaE7QlTAXuoQ',
#     'quadraKills': 0,
#     'riotIdGameName': 'M0DEST0',
#     'riotIdTagline': 'LAN',
#     'role': 'NONE',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 47,
#     'spell2Casts': 30,
#     'spell3Casts': 61,
#     'spell4Casts': 12,
#     'subteamPlacement': 0,
#     'summoner1Casts': 5,
#     'summoner1Id': 4,
#     'summoner2Casts': 9,
#     'summoner2Id': 14,
#     'summonerId': '0U_m8GUm6deRnrPronJ5o-8WYr3d1PprBttP_qlyfBIGjg',
#     'summonerLevel': 321,
#     'summonerName': 'M0DEST0',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'TOP',
#     'timeCCingOthers': 16,
#     'timePlayed': 2499,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 165146,
#     'totalDamageDealtToChampions': 26260,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 47345,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 6234,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 142,
#     'totalTimeCCDealt': 263,
#     'totalTimeSpentDead': 429,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 8511,
#     'trueDamageDealtToChampions': 2601,
#     'trueDamageTaken': 2596,
#     'turretKills': 2,
#     'turretTakedowns': 3,
#     'turretsLost': 11,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 17,
#     'visionWardsBoughtInGame': 1,
#     'wardsKilled': 0,
#     'wardsPlaced': 10,
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 3,
#     'assists': 10,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 1,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 276,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 93,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 1650,
#      'buffsStolen': 2,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.6867191700293545,
#      'controlWardsPlaced': 2,
#      'damagePerMinute': 1428.0261285793713,
#      'damageTakenOnTeamPercentage': 0.2224617104319398,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 6,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 2,
#      'earliestDragonTakedown': 559.1329578,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 18,
#      'enemyJungleMonsterKills': 16,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 969.5400808999999,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 1,
#      'gameLength': 2499.9534369,
#      'goldPerMinute': 507.1997592172434,
#      'hadOpenNexus': 0,
#      'highestChampionDamage': 1,
#      'immobilizeAndKillWithAlly': 10,
#      'initialBuffCount': 3,
#      'initialCrabCount': 1,
#      'jungleCsBefore10Minutes': 64.00000008940697,
#      'junglerKillsEarlyJungle': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 5,
#      'killAfterHiddenWithAlly': 1,
#      'killParticipation': 0.9375,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 3,
#      'killsNearEnemyTurret': 2,
#      'killsOnLanersEarlyJungleAsJungler': 1,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 1,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 3,
#      'laneMinionsFirst10Minutes': 1,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 25.00000011920929,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 2,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': -14.500000029802322,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 3,
#      'multikillsAfterAggressiveFlash': 1,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 6,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 21,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 1,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 2,
#      'skillshotsDodged': 16,
#      'skillshotsHit': 46,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 6,
#      'stealthWardsPlaced': 14,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 30,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 5,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.3466450981369845,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.12974679470062256,
#      'visionScorePerMinute': 0.8494833816463124,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 2},
#     'champExperience': 23046,
#     'champLevel': 18,
#     'championId': 56,
#     'championName': 'Nocturne',
#     'championTransform': 0,
#     'commandPings': 1,
#     'consumablesPurchased': 7,
#     'damageDealtToBuildings': 0,
#     'damageDealtToObjectives': 25892,
#     'damageDealtToTurrets': 0,
#     'damageSelfMitigated': 51995,
#     'dangerPings': 0,
#     'deaths': 6,
#     'detectorWardsPlaced': 2,
#     'doubleKills': 3,
#     'dragonKills': 2,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 1,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 21132,
#     'goldSpent': 21400,
#     'holdPings': 0,
#     'individualPosition': 'JUNGLE',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 4,
#     'item0': 6676,
#     'item1': 3033,
#     'item2': 6692,
#     'item3': 3071,
#     'item4': 3111,
#     'item5': 6696,
#     'item6': 3340,
#     'itemsPurchased': 30,
#     'killingSprees': 4,
#     'kills': 20,
#     'lane': 'JUNGLE',
#     'largestCriticalStrike': 1310,
#     'largestKillingSpree': 6,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 1276,
#     'magicDamageDealt': 3625,
#     'magicDamageDealtToChampions': 3340,
#     'magicDamageTaken': 18806,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 179,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 1,
#     'participantId': 2,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8008, 'var1': 92, 'var2': 20, 'var3': 0},
#         {'perk': 9111, 'var1': 2596, 'var2': 600, 'var3': 0},
#         {'perk': 9104, 'var1': 14, 'var2': 30, 'var3': 0},
#         {'perk': 8014, 'var1': 1487, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8138, 'var1': 18, 'var2': 0, 'var3': 0},
#         {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 308803,
#     'physicalDamageDealtToChampions': 53612,
#     'physicalDamageTaken': 30359,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 6266,
#     'pushPings': 0,
#     'puuid': '3GgmyGhFZN1ViTEot9NYaeNXQyMVdESpfYcpngXQFyRJv45wO5Lpo3IXLxcwRJtKmJqgzvFCtdo5vA',
#     'quadraKills': 0,
#     'riotIdGameName': 'xIRyukIx',
#     'riotIdTagline': 'LAN',
#     'role': 'NONE',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 163,
#     'spell2Casts': 40,
#     'spell3Casts': 40,
#     'spell4Casts': 33,
#     'subteamPlacement': 0,
#     'summoner1Casts': 3,
#     'summoner1Id': 4,
#     'summoner2Casts': 23,
#     'summoner2Id': 11,
#     'summonerId': 'WJGXTyrlrB0Y2QAq1_foKehomv0JiuXZJwUrGVw4kS6CQ3Y',
#     'summonerLevel': 281,
#     'summonerName': 'xIRyukIx',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'JUNGLE',
#     'timeCCingOthers': 272,
#     'timePlayed': 2499,
#     'totalAllyJungleMinionsKilled': 131,
#     'totalDamageDealt': 360523,
#     'totalDamageDealtToChampions': 59499,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 50749,
#     'totalEnemyJungleMinionsKilled': 25,
#     'totalHeal': 20855,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 61,
#     'totalTimeCCDealt': 852,
#     'totalTimeSpentDead': 300,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 48095,
#     'trueDamageDealtToChampions': 2547,
#     'trueDamageTaken': 1584,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 11,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 35,
#     'visionWardsBoughtInGame': 4,
#     'wardsKilled': 0,
#     'wardsPlaced': 16,
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 8,
#     'assists': 7,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 187,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 1550,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 755.808623992016,
#      'damageTakenOnTeamPercentage': 0.16075155930959417,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 7,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 1,
#      'earliestDragonTakedown': 559.1329578,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 448.20001220703125,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 8,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 969.5400808999999,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 1,
#      'gameLength': 2499.9534369,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 399.213779202449,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 1,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 1.8571428571428572,
#      'killAfterHiddenWithAlly': 1,
#      'killParticipation': 0.40625,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 3,
#      'laneMinionsFirst10Minutes': 61,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 106.25,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 2,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 3142,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 12,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 1,
#      'scuttleCrabKills': 1,
#      'skillshotsDodged': 7,
#      'skillshotsHit': 33,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'soloTurretsLategame': 1,
#      'stealthWardsPlaced': 9,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 1,
#      'takedowns': 13,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 2,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.1834681798834674,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 2,
#      'turretTakedowns': 5,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.26029813289642334,
#      'visionScorePerMinute': 0.4155822642451926,
#      'wardTakedowns': 1,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 19953,
#     'champLevel': 18,
#     'championId': 51,
#     'championName': 'Caitlyn',
#     'championTransform': 0,
#     'commandPings': 1,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 9610,
#     'damageDealtToObjectives': 12414,
#     'damageDealtToTurrets': 9610,
#     'damageSelfMitigated': 21142,
#     'dangerPings': 0,
#     'deaths': 7,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': True,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 16633,
#     'goldSpent': 14650,
#     'holdPings': 0,
#     'individualPosition': 'MIDDLE',
#     'inhibitorKills': 1,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 4,
#     'item0': 3142,
#     'item1': 3006,
#     'item2': 6696,
#     'item3': 3036,
#     'item4': 6676,
#     'item5': 1038,
#     'item6': 3340,
#     'itemsPurchased': 24,
#     'killingSprees': 1,
#     'kills': 6,
#     'lane': 'MIDDLE',
#     'largestCriticalStrike': 1427,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 1368,
#     'magicDamageDealt': 1415,
#     'magicDamageDealtToChampions': 845,
#     'magicDamageTaken': 17153,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 4,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 1,
#     'participantId': 3,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8021, 'var1': 2181, 'var2': 1935, 'var3': 0},
#         {'perk': 8009, 'var1': 2272, 'var2': 0, 'var3': 0},
#         {'perk': 9103, 'var1': 27, 'var2': 30, 'var3': 0},
#         {'perk': 8014, 'var1': 768, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8233, 'var1': 21, 'var2': 40, 'var3': 0},
#         {'perk': 8236, 'var1': 48, 'var2': 0, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 241946,
#     'physicalDamageDealtToChampions': 29666,
#     'physicalDamageTaken': 18302,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 3173,
#     'pushPings': 0,
#     'puuid': 'cSqaesq5mi3MGix7AdDk28PwONfU5Rlxih59EEGwA3PUrqTWVzoXw2EyNDwswKuCaaVoTYgv87B-Lw',
#     'quadraKills': 0,
#     'riotIdGameName': 'Alrynank',
#     'riotIdTagline': 'LAN',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 97,
#     'spell2Casts': 33,
#     'spell3Casts': 36,
#     'spell4Casts': 21,
#     'subteamPlacement': 0,
#     'summoner1Casts': 6,
#     'summoner1Id': 7,
#     'summoner2Casts': 5,
#     'summoner2Id': 4,
#     'summonerId': 'JhX0kbqoGde6-5Myc3EpBjXjs95ljR6ucsJfDCw7Ja975RnNAjlA73F0jg',
#     'summonerLevel': 47,
#     'summonerName': 'Alrynank',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'MIDDLE',
#     'timeCCingOthers': 15,
#     'timePlayed': 2499,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 249277,
#     'totalDamageDealtToChampions': 31491,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 36672,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 8611,
#     'totalHealsOnTeammates': 448,
#     'totalMinionsKilled': 237,
#     'totalTimeCCDealt': 79,
#     'totalTimeSpentDead': 316,
#     'totalUnitsHealed': 3,
#     'tripleKills': 0,
#     'trueDamageDealt': 5914,
#     'trueDamageDealtToChampions': 979,
#     'trueDamageTaken': 1215,
#     'turretKills': 4,
#     'turretTakedowns': 5,
#     'turretsLost': 11,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 17,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 9,
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 2,
#     'assists': 7,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 262,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 6,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 542.5697617420293,
#      'damageTakenOnTeamPercentage': 0.12410740607000473,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 6,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 2,
#      'earliestDragonTakedown': 559.1329578,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 1096,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 969.5400808999999,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 1,
#      'gameLength': 2499.9534369,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 292.70286572362284,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 1.5,
#      'killAfterHiddenWithAlly': 1,
#      'killParticipation': 0.28125,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 3,
#      'laneMinionsFirst10Minutes': 29,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 3,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 3142,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 8,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 1,
#      'skillshotsDodged': 12,
#      'skillshotsHit': 163,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 6,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 9,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 2,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.131705677186965,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.3502749800682068,
#      'visionScorePerMinute': 0.2972143674760351,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 1},
#     'champExperience': 16917,
#     'champLevel': 17,
#     'championId': 21,
#     'championName': 'MissFortune',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 1,
#     'damageDealtToBuildings': 0,
#     'damageDealtToObjectives': 3568,
#     'damageDealtToTurrets': 0,
#     'damageSelfMitigated': 15252,
#     'dangerPings': 0,
#     'deaths': 6,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 1,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 12195,
#     'goldSpent': 12675,
#     'holdPings': 0,
#     'individualPosition': 'BOTTOM',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 4,
#     'item0': 6696,
#     'item1': 3142,
#     'item2': 3072,
#     'item3': 3006,
#     'item4': 1018,
#     'item5': 0,
#     'item6': 3340,
#     'itemsPurchased': 19,
#     'killingSprees': 0,
#     'kills': 2,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 833,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 782,
#     'magicDamageDealt': 20092,
#     'magicDamageDealtToChampions': 1907,
#     'magicDamageTaken': 11975,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 2,
#     'neutralMinionsKilled': 8,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 2,
#     'participantId': 4,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8369, 'var1': 802, 'var2': 726, 'var3': 0},
#         {'perk': 8304, 'var1': 11, 'var2': 1, 'var3': 5},
#         {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8233, 'var1': 25, 'var2': 50, 'var3': 0},
#         {'perk': 8236, 'var1': 48, 'var2': 0, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 172952,
#     'physicalDamageDealtToChampions': 19518,
#     'physicalDamageTaken': 15759,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 5636,
#     'pushPings': 0,
#     'puuid': 'FqWjePhOHsQ_5E9dQV0vTnl0Hlu-4DQ5T9otnFcaNOSs5AdzQ-l1oH8p1OX4KkR_5Mhr1obxC650AA',
#     'quadraKills': 0,
#     'riotIdGameName': 'AlucardN06',
#     'riotIdTagline': 'LAN',
#     'role': 'DUO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 165,
#     'spell2Casts': 14,
#     'spell3Casts': 70,
#     'spell4Casts': 13,
#     'subteamPlacement': 0,
#     'summoner1Casts': 7,
#     'summoner1Id': 4,
#     'summoner2Casts': 9,
#     'summoner2Id': 7,
#     'summonerId': 'seHRAgIB7YykZmsq-fOgs4rYETJwFqF54Jpr2XlWM709KSkxlnUSIR9wsw',
#     'summonerLevel': 115,
#     'summonerName': 'AlucardN06',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'BOTTOM',
#     'timeCCingOthers': 8,
#     'timePlayed': 2499,
#     'totalAllyJungleMinionsKilled': 4,
#     'totalDamageDealt': 199561,
#     'totalDamageDealtToChampions': 22606,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 28312,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 9842,
#     'totalHealsOnTeammates': 1096,
#     'totalMinionsKilled': 172,
#     'totalTimeCCDealt': 368,
#     'totalTimeSpentDead': 250,
#     'totalUnitsHealed': 4,
#     'tripleKills': 0,
#     'trueDamageDealt': 6516,
#     'trueDamageDealtToChampions': 1181,
#     'trueDamageTaken': 577,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 11,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 12,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 7,
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 1,
#     'assists': 11,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 308,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 8,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 762.9015060986476,
#      'damageTakenOnTeamPercentage': 0.2851400653720793,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 19,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 969.5400808999999,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 1,
#      'gameLength': 2499.9534369,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 278.8582172387221,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 0.7,
#      'killAfterHiddenWithAlly': 1,
#      'killParticipation': 0.4375,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 1,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 1,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 0,
#      'laneMinionsFirst10Minutes': 27,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 94.00000002980232,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 13,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 24,
#      'skillshotsHit': 0,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 16,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 14,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 3,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.18518993606475892,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 1.159653663635254,
#      'visionScorePerMinute': 0.6772226048886277,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 15070,
#     'champLevel': 16,
#     'championId': 75,
#     'championName': 'Nasus',
#     'championTransform': 0,
#     'commandPings': 4,
#     'consumablesPurchased': 2,
#     'damageDealtToBuildings': 265,
#     'damageDealtToObjectives': 2365,
#     'damageDealtToTurrets': 265,
#     'damageSelfMitigated': 57483,
#     'dangerPings': 0,
#     'deaths': 20,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 1,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 11618,
#     'goldSpent': 12400,
#     'holdPings': 0,
#     'individualPosition': 'UTILITY',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 4,
#     'item0': 6662,
#     'item1': 3074,
#     'item2': 3153,
#     'item3': 3111,
#     'item4': 0,
#     'item5': 0,
#     'item6': 3340,
#     'itemsPurchased': 27,
#     'killingSprees': 0,
#     'kills': 3,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 427,
#     'magicDamageDealt': 29835,
#     'magicDamageDealtToChampions': 8914,
#     'magicDamageTaken': 20894,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 8,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 8,
#     'participantId': 5,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5007},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8008, 'var1': 27, 'var2': 11, 'var3': 0},
#         {'perk': 9111, 'var1': 849, 'var2': 280, 'var3': 0},
#         {'perk': 9104, 'var1': 30, 'var2': 0, 'var3': 0},
#         {'perk': 8014, 'var1': 706, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8210, 'var1': 7, 'var2': 0, 'var3': 0},
#         {'perk': 8236, 'var1': 48, 'var2': 0, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 102844,
#     'physicalDamageDealtToChampions': 22143,
#     'physicalDamageTaken': 41001,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 5636,
#     'pushPings': 0,
#     'puuid': 'WH1hShydsycLS8AbDlbP3n1CyhLzUhJmw6-NvjtvmgKygbXBRhkmgGyHJkPNDCihOJtSpO3f5vx4wg',
#     'quadraKills': 0,
#     'riotIdGameName': 'Lord Mulfgard',
#     'riotIdTagline': 'LAN',
#     'role': 'DUO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 169,
#     'spell2Casts': 46,
#     'spell3Casts': 73,
#     'spell4Casts': 20,
#     'subteamPlacement': 0,
#     'summoner1Casts': 7,
#     'summoner1Id': 12,
#     'summoner2Casts': 10,
#     'summoner2Id': 6,
#     'summonerId': 'FqQonxtauB_fOxMT_UV4XdWxiaxBLi4ZalAQbJyJR-R7tw',
#     'summonerLevel': 540,
#     'summonerName': 'Lord Mulfgard',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'UTILITY',
#     'timeCCingOthers': 33,
#     'timePlayed': 2499,
#     'totalAllyJungleMinionsKilled': 6,
#     'totalDamageDealt': 137075,
#     'totalDamageDealtToChampions': 31786,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 65048,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 17775,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 103,
#     'totalTimeCCDealt': 392,
#     'totalTimeSpentDead': 649,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 4395,
#     'trueDamageDealtToChampions': 729,
#     'trueDamageTaken': 3152,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 11,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 28,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 16,
#     'win': False},
#    {'allInPings': 3,
#     'assistMePings': 18,
#     'assists': 18,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 2,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 341,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 1,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 933.2025373712272,
#      'damageTakenOnTeamPercentage': 0.34958650418543197,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 6,
#      'dodgeSkillShotsSmallWindow': 35,
#      'doubleAces': 0,
#      'dragonTakedowns': 1,
#      'earliestBaron': 2204.2420607999998,
#      'earliestDragonTakedown': 2357.5256403999997,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 2,
#      'gameLength': 2499.9534369,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 356.8809985567496,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 4.333333333333333,
#      'killAfterHiddenWithAlly': 1,
#      'killParticipation': 0.52,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 2,
#      'killsNearEnemyTurret': 2,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 10,
#      'laneMinionsFirst10Minutes': 49,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 1,
#      'maxCsAdvantageOnLaneOpponent': 83,
#      'maxKillDeficit': 1,
#      'maxLevelLeadLaneOpponent': 4,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 1,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 3084,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 18,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 1,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 1,
#      'skillshotsDodged': 217,
#      'skillshotsHit': 76,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 1,
#      'stealthWardsPlaced': 14,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 26,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 2,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 1,
# ...
#      'maxKillDeficit': 1,
#      'maxLevelLeadLaneOpponent': 2,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 1,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6671,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 18,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 39,
#      'skillshotsHit': 20,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 5,
#      'soloTurretsLategame': 2,
#      'stealthWardsPlaced': 9,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 28,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 3,
#      'takedownsInAlcove': 1,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 1,
#      'teamDamagePercentage': 0.23802588182217027,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 1,
#      'thirdInhibitorDestroyedTime': 2418.4503061,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 3,
#      'turretTakedowns': 4,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.5391126871109009,
#      'visionScorePerMinute': 0.45744640151874205,
#      'wardTakedowns': 2,
#      'wardTakedownsBefore20M': 2,
#      'wardsGuarded': 0},
#     'champExperience': 19709,
#     'champLevel': 18,
#     'championId': 202,
#     'championName': 'Jhin',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 4,
#     'damageDealtToBuildings': 9521,
#     'damageDealtToObjectives': 20252,
#     'damageDealtToTurrets': 9521,
#     'damageSelfMitigated': 12605,
#     'dangerPings': 0,
#     'deaths': 5,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 1,
#     'dragonKills': 1,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 1,
#     'enemyVisionPings': 2,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 17437,
#     'goldSpent': 17200,
#     'holdPings': 0,
#     'individualPosition': 'BOTTOM',
#     'inhibitorKills': 1,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 1,
#     'item0': 3009,
#     'item1': 6671,
#     'item2': 3095,
#     'item3': 3094,
#     'item4': 3072,
#     'item5': 3036,
#     'item6': 3340,
#     'itemsPurchased': 27,
#     'killingSprees': 2,
#     'kills': 12,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 1465,
#     'largestKillingSpree': 7,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 1653,
#     'magicDamageDealt': 17408,
#     'magicDamageDealtToChampions': 6910,
#     'magicDamageTaken': 4757,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 4,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 6,
#     'participantId': 9,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8021, 'var1': 3418, 'var2': 3854, 'var3': 0},
#         {'perk': 9111, 'var1': 2284, 'var2': 560, 'var3': 0},
#         {'perk': 9103, 'var1': 25, 'var2': 0, 'var3': 0},
#         {'perk': 8014, 'var1': 1118, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8138, 'var1': 18, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 450, 'var2': 5, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 191987,
#     'physicalDamageDealtToChampions': 36722,
#     'physicalDamageTaken': 22498,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 6364,
#     'pushPings': 0,
#     'puuid': 'fqGjV8P6gkhsge0WKk_uXVxMW7l17-uzfm4aukMfnwBg23nJiHQEIXma0wrxw5wBSYaotD8M_WpJDQ',
#     'quadraKills': 0,
#     'riotIdGameName': 'Pianoquehabla',
#     'riotIdTagline': '7507',
#     'role': 'CARRY',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 99,
#     'spell2Casts': 37,
#     'spell3Casts': 41,
#     'spell4Casts': 39,
#     'subteamPlacement': 0,
#     'summoner1Casts': 3,
#     'summoner1Id': 4,
#     'summoner2Casts': 3,
#     'summoner2Id': 14,
#     'summonerId': '0RCd5Fu2NVCYATGcu30E6LNBqWuDI2wFj99sIGUC5JcpaNHJFcs9_DFmbQ',
#     'summonerLevel': 111,
#     'summonerName': 'Pianoquehabla',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'BOTTOM',
#     'timeCCingOthers': 43,
#     'timePlayed': 2499,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 209907,
#     'totalDamageDealtToChampions': 44144,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 27777,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 11215,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 190,
#     'totalTimeCCDealt': 131,
#     'totalTimeSpentDead': 267,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 512,
#     'trueDamageDealtToChampions': 512,
#     'trueDamageTaken': 521,
#     'turretKills': 3,
#     'turretTakedowns': 4,
#     'turretsLost': 6,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 19,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 2,
#     'wardsPlaced': 9,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 19,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 129,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 244.38998932220474,
#      'damageTakenOnTeamPercentage': 0.10000254224864677,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 7,
#      'dodgeSkillShotsSmallWindow': 18,
#      'doubleAces': 0,
#      'dragonTakedowns': 2,
#      'earliestBaron': 2204.2420607999998,
#      'earliestDragonTakedown': 1626.230892,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 5452.83447265625,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 29,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 2,
#      'gameLength': 2499.9534369,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 240.34844529747733,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 8,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 3.142857142857143,
#      'killAfterHiddenWithAlly': 1,
#      'killParticipation': 0.44,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 12,
#      'laneMinionsFirst10Minutes': 2,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 1,
#      'maxCsAdvantageOnLaneOpponent': 0,
#      'maxKillDeficit': 1,
#      'maxLevelLeadLaneOpponent': 2,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6620,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 18,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 104,
#      'skillshotsHit': 58,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 7,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 22,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 2,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 1,
#      'teamDamagePercentage': 0.05490483930383918,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 1,
#      'thirdInhibitorDestroyedTime': 2418.4503061,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 3,
#      'turretTakedowns': 2,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.5369627475738525,
#      'visionScorePerMinute': 0.31357926578205303,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 15749,
#     'champLevel': 16,
#     'championId': 147,
#     'championName': 'Seraphine',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 2,
#     'damageDealtToBuildings': 1261,
#     'damageDealtToObjectives': 3009,
#     'damageDealtToTurrets': 1261,
#     'damageSelfMitigated': 8815,
#     'dangerPings': 0,
#     'deaths': 7,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 10014,
#     'goldSpent': 8450,
#     'holdPings': 0,
#     'individualPosition': 'UTILITY',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 1,
#     'item0': 3853,
#     'item1': 0,
#     'item2': 6620,
#     'item3': 3158,
#     'item4': 3116,
#     'item5': 3011,
#     'item6': 3340,
#     'itemsPurchased': 17,
#     'killingSprees': 0,
#     'kills': 3,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 894,
#     'magicDamageDealt': 33696,
#     'magicDamageDealtToChampions': 9339,
#     'magicDamageTaken': 2408,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 10,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8214, 'var1': 902, 'var2': 342, 'var3': 0},
#         {'perk': 8226, 'var1': 250, 'var2': 199, 'var3': 0},
#         {'perk': 8210, 'var1': 19, 'var2': 0, 'var3': 0},
#         {'perk': 8237, 'var1': 457, 'var2': 0, 'var3': 0}],
#        'style': 8200},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 5048,
#     'physicalDamageDealtToChampions': 843,
#     'physicalDamageTaken': 18192,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 5922,
#     'pushPings': 0,
#     'puuid': '-c1z5kmm2qxDlHX94c3ing647J0bQmVi5aG2w57zj2eB8nWIr_Ef8s-OiHRulY7lZdZxjjclSH5ebg',
#     'quadraKills': 0,
#     'riotIdGameName': 'MapacheÁcido',
#     'riotIdTagline': 'LAN',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 48,
#     'spell2Casts': 26,
#     'spell3Casts': 49,
#     'spell4Casts': 6,
#     'subteamPlacement': 0,
#     'summoner1Casts': 3,
#     'summoner1Id': 4,
#     'summoner2Casts': 3,
#     'summoner2Id': 7,
#     'summonerId': 'IbYGNE-X__RzOhp23Tbj5K3jYbLutjX47rW8D1M-D1hZMVujb_w3Rvs_8g',
#     'summonerLevel': 25,
#     'summonerName': 'MapacheÁcido',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'UTILITY',
#     'timeCCingOthers': 30,
#     'timePlayed': 2499,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 38744,
#     'totalDamageDealtToChampions': 10182,
#     'totalDamageShieldedOnTeammates': 2343,
#     'totalDamageTaken': 21051,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 4314,
#     'totalHealsOnTeammates': 3109,
#     'totalMinionsKilled': 17,
#     'totalTimeCCDealt': 181,
#     'totalTimeSpentDead': 229,
#     'totalUnitsHealed': 5,
#     'tripleKills': 0,
#     'trueDamageDealt': 0,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 450,
#     'turretKills': 1,
#     'turretTakedowns': 2,
#     'turretsLost': 6,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 13,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 7,
#     'win': True}],
#   'platformId': 'LA1',
#   'queueId': 490,
#   'teams': [{'bans': [],
#     'objectives': {'baron': {'first': False, 'kills': 0},
#      'champion': {'first': False, 'kills': 32},
#      'dragon': {'first': True, 'kills': 2},
#      'horde': {'first': False, 'kills': 0},
#      'inhibitor': {'first': True, 'kills': 1},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': True, 'kills': 6}},
#     'teamId': 100,
#     'win': False},
#    {'bans': [],
#     'objectives': {'baron': {'first': True, 'kills': 1},
#      'champion': {'first': True, 'kills': 51},
#      'dragon': {'first': False, 'kills': 4},
#      'horde': {'first': False, 'kills': 0},
#      'inhibitor': {'first': False, 'kills': 4},
#      'riftHerald': {'first': True, 'kills': 1},
#      'tower': {'first': False, 'kills': 11}},
#     'teamId': 200,
#     'win': True}],
#   'tournamentCode': ''}}

# %%
# Given the match data and a players puuid, return the data about just them
def find_player_data(match_data, puuid):
    participants = match_data['metadata']['participants']
    player_index = participants.index(puuid)
    player_data = match_data['info']['participants'][player_index]
    return player_data

# %%
find_player_data(match_data, puuid)
# Out:
# {'allInPings': 0,
#  'assistMePings': 0,
#  'assists': 9,
#  'baitPings': 0,
#  'baronKills': 0,
#  'basicPings': 0,
#  'bountyLevel': 0,
#  'challenges': {'12AssistStreakCount': 0,
#   'abilityUses': 150,
#   'acesBefore15Minutes': 0,
#   'alliedJungleMonsterKills': 0,
#   'baronTakedowns': 0,
#   'blastConeOppositeOpponentCount': 0,
#   'bountyGold': 0,
#   'buffsStolen': 0,
#   'completeSupportQuestInTime': 0,
#   'controlWardTimeCoverageInRiverOrEnemyHalf': 0.6762572322932532,
#   'controlWardsPlaced': 1,
#   'damagePerMinute': 630.2564261771992,
#   'damageTakenOnTeamPercentage': 0.20753925881638197,
#   'dancedWithRiftHerald': 0,
#   'deathsByEnemyChamps': 12,
#   'dodgeSkillShotsSmallWindow': 0,
#   'doubleAces': 0,
#   'dragonTakedowns': 0,
#   'earlyLaningPhaseGoldExpAdvantage': 0,
#   'effectiveHealAndShielding': 0,
#   'elderDragonKillsWithOpposingSoul': 0,
#   'elderDragonMultikills': 0,
#   'enemyChampionImmobilizations': 8,
#   'enemyJungleMonsterKills': 0,
#   'epicMonsterKillsNearEnemyJungler': 0,
#   'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#   'epicMonsterSteals': 0,
#   'epicMonsterStolenWithoutSmite': 0,
#   'firstTurretKilled': 1,
#   'firstTurretKilledTime': 969.5400808999999,
#   'flawlessAces': 0,
#   'fullTeamTakedown': 1,
#   'gameLength': 2499.9534369,
#   'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#   'goldPerMinute': 262.9467177582255,
#   'hadOpenNexus': 0,
#   'immobilizeAndKillWithAlly': 2,
#   'initialBuffCount': 0,
#   'initialCrabCount': 0,
#   'jungleCsBefore10Minutes': 0,
#   'junglerTakedownsNearDamagedEpicMonster': 0,
#   'kTurretsDestroyedBeforePlatesFall': 0,
#   'kda': 0.8333333333333334,
#   'killAfterHiddenWithAlly': 1,
#   'killParticipation': 0.3125,
#   'killedChampTookFullTeamDamageSurvived': 0,
#   'killingSprees': 0,
#   'killsNearEnemyTurret': 1,
#   'killsOnOtherLanesEarlyJungleAsLaner': 0,
#   'killsOnRecentlyHealedByAramPack': 0,
#   'killsUnderOwnTurret': 0,
#   'killsWithHelpFromEpicMonster': 0,
#   'knockEnemyIntoTeamAndKill': 0,
#   'landSkillShotsEarlyGame': 0,
#   'laneMinionsFirst10Minutes': 42,
#   'laningPhaseGoldExpAdvantage': 0,
#   'legendaryCount': 0,
#   'lostAnInhibitor': 0,
#   'maxCsAdvantageOnLaneOpponent': 7,
#   'maxKillDeficit': 0,
#   'maxLevelLeadLaneOpponent': 1,
#   'mejaisFullStackInTime': 0,
#   'moreEnemyJungleThanOpponent': 0,
#   'multiKillOneSpell': 0,
#   'multiTurretRiftHeraldCount': 0,
#   'multikills': 0,
#   'multikillsAfterAggressiveFlash': 0,
#   'mythicItemUsed': 6665,
#   'outerTurretExecutesBefore10Minutes': 0,
#   'outnumberedKills': 0,
#   'outnumberedNexusKill': 0,
#   'perfectDragonSoulsTaken': 0,
#   'perfectGame': 0,
#   'pickKillWithAlly': 10,
#   'playedChampSelectPosition': 1,
#   'poroExplosions': 0,
#   'quickCleanse': 0,
#   'quickFirstTurret': 0,
#   'quickSoloKills': 0,
#   'riftHeraldTakedowns': 0,
#   'saveAllyFromDeath': 0,
#   'scuttleCrabKills': 0,
#   'skillshotsDodged': 25,
#   'skillshotsHit': 0,
#   'snowballsHit': 0,
#   'soloBaronKills': 0,
#   'soloKills': 0,
#   'soloTurretsLategame': 1,
#   'stealthWardsPlaced': 9,
#   'survivedSingleDigitHpCount': 0,
#   'survivedThreeImmobilizesInFight': 0,
#   'takedownOnFirstTurret': 1,
#   'takedowns': 10,
#   'takedownsAfterGainingLevelAdvantage': 0,
#   'takedownsBeforeJungleMinionSpawn': 0,
#   'takedownsFirstXMinutes': 1,
#   'takedownsInAlcove': 0,
#   'takedownsInEnemyFountain': 0,
#   'teamBaronKills': 0,
#   'teamDamagePercentage': 0.15299110872782412,
#   'teamElderDragonKills': 0,
#   'teamRiftHeraldKills': 0,
#   'tookLargeDamageSurvived': 0,
#   'turretPlatesTaken': 0,
#   'turretTakedowns': 3,
#   'turretsTakenWithRiftHerald': 0,
#   'twentyMinionsIn3SecondsCount': 0,
#   'twoWardsOneSweeperCount': 0,
#   'unseenRecalls': 0,
#   'visionScoreAdvantageLaneOpponent': -0.3400420546531677,
#   'visionScorePerMinute': 0.4140210779411605,
#   'wardTakedowns': 0,
#   'wardTakedownsBefore20M': 0,
#   'wardsGuarded': 0},
#  'champExperience': 17459,
#  'champLevel': 17,
#  'championId': 106,
#  'championName': 'Volibear',
#  'championTransform': 0,
#  'commandPings': 0,
#  'consumablesPurchased': 3,
#  'damageDealtToBuildings': 4831,
#  'damageDealtToObjectives': 4831,
#  'damageDealtToTurrets': 4831,
#  'damageSelfMitigated': 55838,
#  'dangerPings': 0,
#  'deaths': 12,
#  'detectorWardsPlaced': 1,
#  'doubleKills': 0,
#  'dragonKills': 0,
#  'eligibleForProgression': True,
#  'enemyMissingPings': 0,
#  'enemyVisionPings': 0,
#  'firstBloodAssist': False,
#  'firstBloodKill': False,
#  'firstTowerAssist': False,
#  'firstTowerKill': False,
#  'gameEndedInEarlySurrender': False,
#  'gameEndedInSurrender': False,
#  'getBackPings': 0,
#  'goldEarned': 10955,
#  'goldSpent': 10125,
#  'holdPings': 0,
#  'individualPosition': 'TOP',
#  'inhibitorKills': 0,
#  'inhibitorTakedowns': 0,
#  'inhibitorsLost': 4,
#  'item0': 1056,
#  'item1': 3115,
#  'item2': 6665,
#  'item3': 3111,
#  'item4': 3211,
#  'item5': 3067,
#  'item6': 3340,
#  'itemsPurchased': 18,
#  'killingSprees': 0,
#  'kills': 1,
#  'lane': 'JUNGLE',
#  'largestCriticalStrike': 0,
#  'largestKillingSpree': 0,
#  'largestMultiKill': 1,
#  'longestTimeSpentLiving': 552,
#  'magicDamageDealt': 111101,
#  'magicDamageDealtToChampions': 15229,
#  'magicDamageTaken': 17225,
#  'missions': {'playerScore0': 0,
#   'playerScore1': 0,
#   'playerScore10': 0,
#   'playerScore11': 0,
#   'playerScore2': 0,
#   'playerScore3': 0,
#   'playerScore4': 0,
#   'playerScore5': 0,
#   'playerScore6': 0,
#   'playerScore7': 0,
#   'playerScore8': 0,
#   'playerScore9': 0},
#  'needVisionPings': 0,
#  'neutralMinionsKilled': 0,
#  'nexusKills': 0,
#  'nexusLost': 1,
#  'nexusTakedowns': 0,
#  'objectivesStolen': 0,
#  'objectivesStolenAssists': 0,
#  'onMyWayPings': 0,
#  'participantId': 1,
#  'pentaKills': 0,
#  'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#   'styles': [{'description': 'primaryStyle',
#     'selections': [{'perk': 8008, 'var1': 46, 'var2': 11, 'var3': 0},
#      {'perk': 9111, 'var1': 913, 'var2': 200, 'var3': 0},
#      {'perk': 9104, 'var1': 33, 'var2': 50, 'var3': 0},
#      {'perk': 8299, 'var1': 1143, 'var2': 0, 'var3': 0}],
#     'style': 8000},
#    {'description': 'subStyle',
#     'selections': [{'perk': 8446, 'var1': 916, 'var2': 0, 'var3': 0},
#      {'perk': 8453, 'var1': 814, 'var2': 404, 'var3': 0}],
#     'style': 8400}]},
#  'physicalDamageDealt': 45532,
#  'physicalDamageDealtToChampions': 8428,
#  'physicalDamageTaken': 27523,
#  'placement': 0,
#  'playerAugment1': 0,
#  'playerAugment2': 0,
#  'playerAugment3': 0,
#  'playerAugment4': 0,
#  'playerScore0': 0,
#  'playerScore1': 0,
#  'playerScore10': 0,
#  'playerScore11': 0,
#  'playerScore2': 0,
#  'playerScore3': 0,
#  'playerScore4': 0,
#  'playerScore5': 0,
#  'playerScore6': 0,
#  'playerScore7': 0,
#  'playerScore8': 0,
#  'playerScore9': 0,
#  'playerSubteamId': 0,
#  'profileIcon': 5497,
#  'pushPings': 0,
#  'puuid': 'ug6gjzUWzBgSY9Q2M4whHHKo_oyCatFoIuhcJHWwW6whTGrSutmObCCdtLGDqihAp5xaE7QlTAXuoQ',
#  'quadraKills': 0,
#  'riotIdGameName': 'M0DEST0',
#  'riotIdTagline': 'LAN',
#  'role': 'NONE',
#  'sightWardsBoughtInGame': 0,
#  'spell1Casts': 47,
#  'spell2Casts': 30,
#  'spell3Casts': 61,
#  'spell4Casts': 12,
#  'subteamPlacement': 0,
#  'summoner1Casts': 5,
#  'summoner1Id': 4,
#  'summoner2Casts': 9,
#  'summoner2Id': 14,
#  'summonerId': '0U_m8GUm6deRnrPronJ5o-8WYr3d1PprBttP_qlyfBIGjg',
#  'summonerLevel': 321,
#  'summonerName': 'M0DEST0',
#  'teamEarlySurrendered': False,
#  'teamId': 100,
#  'teamPosition': 'TOP',
#  'timeCCingOthers': 16,
#  'timePlayed': 2499,
#  'totalAllyJungleMinionsKilled': 0,
#  'totalDamageDealt': 165146,
#  'totalDamageDealtToChampions': 26260,
#  'totalDamageShieldedOnTeammates': 0,
#  'totalDamageTaken': 47345,
#  'totalEnemyJungleMinionsKilled': 0,
#  'totalHeal': 6234,
#  'totalHealsOnTeammates': 0,
#  'totalMinionsKilled': 142,
#  'totalTimeCCDealt': 263,
#  'totalTimeSpentDead': 429,
#  'totalUnitsHealed': 1,
#  'tripleKills': 0,
#  'trueDamageDealt': 8511,
#  'trueDamageDealtToChampions': 2601,
#  'trueDamageTaken': 2596,
#  'turretKills': 2,
#  'turretTakedowns': 3,
#  'turretsLost': 11,
#  'unrealKills': 0,
#  'visionClearedPings': 0,
#  'visionScore': 17,
#  'visionWardsBoughtInGame': 1,
#  'wardsKilled': 0,
#  'wardsPlaced': 10,
#  'win': False}

# %% [markdown]
# We haven't done anything new above, just put everything into functions so it's easier to call them later!

# %% [markdown]
# Now, let's say we want to look at our last 20 games and extract the data \
# To do this, we simply loop through the list of match ids and perform the functions \
# For my example, each time we'll save information about the Champion, KDA and Result

# %%
# We initialise an empty dictionary to store data for each game
data = {
    'champion': [],
    'kills': [],
    'deaths': [],
    'assists': [],
    'win': []
}

for match_id in match_ids:
    print(match_id)
    
    # run the two functions to get the player data from the match ID
    match_data = get_match_data(match_id, mass_region, api_key)
    player_data = find_player_data(match_data, puuid)
    
    # assign the variables we're interested in
    champion = player_data['championName']
    k = player_data['kills']
    d = player_data['deaths']
    a = player_data['assists']
    win = player_data['win']
     
    # add them to our dataset
    data['champion'].append(champion)
    data['kills'].append(k)
    data['deaths'].append(d)
    data['assists'].append(a)
    data['win'].append(win)
# Out:
# LA1_1460596933
# LA1_1460572182
# LA1_1460549970
# LA1_1460533557
# LA1_1460494945
# LA1_1459873188
# LA1_1459871292
# LA1_1459857257
# LA1_1459837219
# LA1_1459699435
# LA1_1459689802
# LA1_1459681842
# LA1_1459675534
# LA1_1459662989
# LA1_1459642993
# LA1_1458661840
# LA1_1458641722
# LA1_1458622715
# LA1_1458611574
# LA1_1458258515

# %%
# Data on the last 20 games of the account in question
data
# Out:
# {'champion': ['Volibear',
#   'Sett',
#   'Sett',
#   'Volibear',
#   'Teemo',
#   'Mordekaiser',
#   'Mordekaiser',
#   'Teemo',
#   'Mordekaiser',
#   'Gwen',
#   'Mordekaiser',
#   'Warwick',
#   'Amumu',
#   'Belveth',
#   'Volibear',
#   'Katarina',
#   'Caitlyn',
#   'Karthus',
#   'Mordekaiser',
#   'Volibear'],
#  'kills': [1, 6, 6, 2, 9, 3, 0, 8, 10, 5, 4, 5, 1, 2, 3, 5, 13, 10, 7, 6],
#  'deaths': [12, 10, 3, 7, 9, 9, 0, 3, 10, 7, 4, 5, 8, 6, 8, 17, 22, 21, 9, 12],
#  'assists': [9,
#   26,
#   10,
#   3,
#   6,
#   5,
#   0,
#   6,
#   15,
#   11,
#   7,
#   7,
#   4,
#   9,
#   4,
#   12,
#   34,
#   37,
#   7,
#   16],
#  'win': [False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False]}

# %% [markdown]
# The next step requires the "pandas" package \
# You may already have this installed, if not: https://pandas.pydata.org/getting_started.html

# %%
import pandas as pd # the "as" part just renames it to make it quicker to type

# %% [markdown]
# We'll now convert our data dictionary into a dataframe

# %%
df = pd.DataFrame(data)
df
# Out:
#        champion  kills  deaths  assists    win
# 0      Volibear      1      12        9  False
# 1          Sett      6      10       26   True
# 2          Sett      6       3       10   True
# 3      Volibear      2       7        3   True
# 4         Teemo      9       9        6   True
# 5   Mordekaiser      3       9        5  False
# 6   Mordekaiser      0       0        0  False
# 7         Teemo      8       3        6   True
# 8   Mordekaiser     10      10       15  False
# 9          Gwen      5       7       11  False
# 10  Mordekaiser      4       4        7   True
# 11      Warwick      5       5        7   True
# 12        Amumu      1       8        4  False
# 13      Belveth      2       6        9  False
# 14     Volibear      3       8        4  False
# 15     Katarina      5      17       12  False
# 16      Caitlyn     13      22       34  False
# 17      Karthus     10      21       37   True
# 18  Mordekaiser      7       9        7  False
# 19     Volibear      6      12       16  False

# %% [markdown]
# We'll also convert the previous code into a function for later use

# %%
def gather_all_data(puuid, match_ids, mass_region, api_key):
    # We initialise an empty dictionary to store data for each game
    data = {
        'champion': [],
        'kills': [],
        'deaths': [],
        'assists': [],
        'win': []
    }

    for match_id in match_ids:
        print(match_id)

        # run the two functions to get the player data from the match ID
        match_data = get_match_data(match_id, mass_region, api_key)
        player_data = find_player_data(match_data, puuid)

        # assign the variables we're interested in
        champion = player_data['championName']
        k = player_data['kills']
        d = player_data['deaths']
        a = player_data['assists']
        win = player_data['win']

        # add them to our dataset
        data['champion'].append(champion)
        data['kills'].append(k)
        data['deaths'].append(d)
        data['assists'].append(a)
        data['win'].append(win)    
    
    df = pd.DataFrame(data)
    
    return df

# %%
df = gather_all_data(puuid, match_ids, mass_region, api_key)
# Out:
# LA1_1460596933
# LA1_1460572182
# LA1_1460549970
# LA1_1460533557
# LA1_1460494945
# LA1_1459873188
# LA1_1459871292
# LA1_1459857257
# LA1_1459837219
# LA1_1459699435
# LA1_1459689802
# LA1_1459681842
# LA1_1459675534
# LA1_1459662989
# LA1_1459642993
# LA1_1458661840
# LA1_1458641722
# LA1_1458622715
# LA1_1458611574
# LA1_1458258515

# %%
df
# Out:
#        champion  kills  deaths  assists    win
# 0      Volibear      1      12        9  False
# 1          Sett      6      10       26   True
# 2          Sett      6       3       10   True
# 3      Volibear      2       7        3   True
# 4         Teemo      9       9        6   True
# 5   Mordekaiser      3       9        5  False
# 6   Mordekaiser      0       0        0  False
# 7         Teemo      8       3        6   True
# 8   Mordekaiser     10      10       15  False
# 9          Gwen      5       7       11  False
# 10  Mordekaiser      4       4        7   True
# 11      Warwick      5       5        7   True
# 12        Amumu      1       8        4  False
# 13      Belveth      2       6        9  False
# 14     Volibear      3       8        4  False
# 15     Katarina      5      17       12  False
# 16      Caitlyn     13      22       34  False
# 17      Karthus     10      21       37   True
# 18  Mordekaiser      7       9        7  False
# 19     Volibear      6      12       16  False

# %% [markdown]
# As you can see, the "win" colun is a boolean (True or False) \
# To make it easier to use, we'll convert it to an int (1 or 0)

# %%
df['win'] = df['win'].astype(int)

# %%
df
# Out:
#        champion  kills  deaths  assists  win
# 0      Volibear      1      12        9    0
# 1          Sett      6      10       26    1
# 2          Sett      6       3       10    1
# 3      Volibear      2       7        3    1
# 4         Teemo      9       9        6    1
# 5   Mordekaiser      3       9        5    0
# 6   Mordekaiser      0       0        0    0
# 7         Teemo      8       3        6    1
# 8   Mordekaiser     10      10       15    0
# 9          Gwen      5       7       11    0
# 10  Mordekaiser      4       4        7    1
# 11      Warwick      5       5        7    1
# 12        Amumu      1       8        4    0
# 13      Belveth      2       6        9    0
# 14     Volibear      3       8        4    0
# 15     Katarina      5      17       12    0
# 16      Caitlyn     13      22       34    0
# 17      Karthus     10      21       37    1
# 18  Mordekaiser      7       9        7    0
# 19     Volibear      6      12       16    0

# %% [markdown]
# Now we have it as a dataframe, it's much easier to do what we want, such as:

# %%
# Find the averages
df.mean(numeric_only=True) # numeric_only stops it trying to average the "champion" column
# Out:
# kills       5.3
# deaths      9.1
# assists    11.4
# win         0.4
# dtype: float64

# %%
# Get the averages per champion
df.groupby('champion').mean()
# Out:
#              kills  deaths  assists   win
# champion
# Amumu          1.0    8.00      4.0  0.00
# Belveth        2.0    6.00      9.0  0.00
# Caitlyn       13.0   22.00     34.0  0.00
# Gwen           5.0    7.00     11.0  0.00
# Karthus       10.0   21.00     37.0  1.00
# Katarina       5.0   17.00     12.0  0.00
# Mordekaiser    4.8    6.40      6.8  0.20
# Sett           6.0    6.50     18.0  1.00
# Teemo          8.5    6.00      6.0  1.00
# Volibear       3.0    9.75      8.0  0.25
# Warwick        5.0    5.00      7.0  1.00

# %%
# or maybe order your games by amount of kills
df.sort_values('kills')
# Out:
#        champion  kills  deaths  assists  win
# 6   Mordekaiser      0       0        0    0
# 0      Volibear      1      12        9    0
# 12        Amumu      1       8        4    0
# 3      Volibear      2       7        3    1
# 13      Belveth      2       6        9    0
# 14     Volibear      3       8        4    0
# 5   Mordekaiser      3       9        5    0
# 10  Mordekaiser      4       4        7    1
# 15     Katarina      5      17       12    0
# 11      Warwick      5       5        7    1
# 9          Gwen      5       7       11    0
# 2          Sett      6       3       10    1
# 1          Sett      6      10       26    1
# 19     Volibear      6      12       16    0
# 18  Mordekaiser      7       9        7    0
# 7         Teemo      8       3        6    1
# 4         Teemo      9       9        6    1
# 8   Mordekaiser     10      10       15    0
# 17      Karthus     10      21       37    1
# 16      Caitlyn     13      22       34    0

# %% [markdown]
# ### Adding arguments to the API calls

# %% [markdown]
# 20 games really isn't enough to evaluate an account, and it also includes ARAMs and Normals which you may not want \
# So let's go back to one of our functions and add some arguments

# %%
# The original function
def get_match_ids(puuid, mass_region, api_key):
    api_url = (
        "https://" +
        mass_region +
        ".api.riotgames.com/lol/match/v5/matches/by-puuid/" +
        puuid + 
        "/ids?start=0&count=20" + 
        "&api_key=" + 
        api_key
    )
    
    print(api_url)
    
    resp = requests.get(api_url)
    match_ids = resp.json()
    return match_ids

# %% [markdown]
# As you can see from the original function there is already an argument for "count=20" \
# So all we need to do is replace that with a variable of our choice

# %%
# Updated function where you can set how many games you want
def get_match_ids(puuid, mass_region, no_games, api_key):
    api_url = (
        "https://" +
        mass_region +
        ".api.riotgames.com/lol/match/v5/matches/by-puuid/" +
        puuid + 
        "/ids?start=0" + 
        "&count=" +
        str(no_games) + 
        "&api_key=" + 
        api_key
    )
    
    print(api_url)
    
    resp = requests.get(api_url)
    match_ids = resp.json()
    return match_ids

# %%
no_games = 25 # Leave this as 25 for now, otherwise you may run into issues that we cover shortly!

match_ids = get_match_ids(puuid, mass_region, no_games, api_key)

print(len(match_ids))
# Out:
# https://AMERICAS.api.riotgames.com/lol/match/v5/matches/by-puuid/ug6gjzUWzBgSY9Q2M4whHHKo_oyCatFoIuhcJHWwW6whTGrSutmObCCdtLGDqihAp5xaE7QlTAXuoQ/ids?start=0&count=25&api_key=RGAPI-3ee6f984-bd4e-43fe-a855-51c08b131105
# 25

# %% [markdown]
# But let's say we ONLY want data from a certain queue type (I'll use Ranked Solos) \
# How do we know what argument to use?

# %% [markdown]
# Go back to the portal, return to MATCH-V5 (on the left) and open "/lol/match/v5/matches/by-puuid/{puuid}/ids" again \
#
# Scroll to the bottom and fill in the form again with the same puuid, region and app \
# Except this time, also add "420" to the "queue" input then EXECUTE REQUEST
#
# Copy and paste the REQUEST URL

# %%
"https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/ug6gjzUWzBgSY9Q2M4whHHKo_oyCatFoIuhcJHWwW6whTGrSutmObCCdtLGDqihAp5xaE7QlTAXuoQ/ids?start=0&count=25&api_key=RGAPI-3ee6f984-bd4e-43fe-a855-51c08b131105"
# Out:
# 'https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/ug6gjzUWzBgSY9Q2M4whHHKo_oyCatFoIuhcJHWwW6whTGrSutmObCCdtLGDqihAp5xaE7QlTAXuoQ/ids?start=0&count=25&api_key=RGAPI-3ee6f984-bd4e-43fe-a855-51c08b131105'

# %% [markdown]
# As you can see, there's a new argument: "queue=420"
#
# If you wondering where to find all the queue types, you can go here: https://static.developer.riotgames.com/docs/lol/queues.json
#
# Simply find the queue type you want from the description and replace the "queue" with the queueId
#
# Let's add this into our function

# %%
# Updated function where you can set which queue to take data from
def get_match_ids(puuid, mass_region, no_games, queue_id, api_key):
    api_url = (
        "https://" +
        mass_region +
        ".api.riotgames.com/lol/match/v5/matches/by-puuid/" +
        puuid + 
        "/ids?start=0" + 
        "&count=" +
        str(no_games) + 
        "&queue=" + 
        str(queue_id) + 
        "&api_key=" + 
        api_key
    )
    
    print(api_url)
    
    resp = requests.get(api_url)
    match_ids = resp.json()
    return match_ids

# %%
queue_id = 420

match_ids = get_match_ids(puuid, mass_region, no_games, queue_id, api_key)
match_ids

# Experiment with changing to different queue_ids
# For ones that don't exist, the match_ids should be an empty list
# Out:
# https://AMERICAS.api.riotgames.com/lol/match/v5/matches/by-puuid/ug6gjzUWzBgSY9Q2M4whHHKo_oyCatFoIuhcJHWwW6whTGrSutmObCCdtLGDqihAp5xaE7QlTAXuoQ/ids?start=0&count=25&queue=420&api_key=RGAPI-3ee6f984-bd4e-43fe-a855-51c08b131105
# ['LA1_1459873188',
#  'LA1_1459871292',
#  'LA1_1459857257',
#  'LA1_1459837219',
#  'LA1_1452769007',
#  'LA1_1452710747',
#  'LA1_1452707175',
#  'LA1_1452692240',
#  'LA1_1451985705',
#  'LA1_1445153257',
#  'LA1_1445143639',
#  'LA1_1445085347',
#  'LA1_1444249143',
#  'LA1_1443950772',
#  'LA1_1443441739',
#  'LA1_1443417553',
#  'LA1_1443146122',
#  'LA1_1441906091',
#  'LA1_1441882430',
#  'LA1_1440776007',
#  'LA1_1439500354',
#  'LA1_1439489253',
#  'LA1_1439475137',
#  'LA1_1439183542',
#  'LA1_1439165725']

# %% [markdown]
# ### Rate Limits

# %% [markdown]
# If you return to the home page of the developer portal \
# https://developer.riotgames.com/ \
# Under your API key you'll see: RATE LIMITS \
# This is currently set to 20 per second & 100 per 2 minutes
#
# So what happens if we go over it? \
# Let's send off the same API request over 100 times to see:

# %%
# NOTE, we're sending off the same match ID 200 times, which isn't useful and only for the example
# yours may break before you reach 100, depending how fast you're going through the notebook
for i in range(200):
    print("Attempt:", i)
    match_data = get_match_data(match_id, mass_region, api_key)
    print("Match Duration:", match_data['info']['gameDuration'])
# Out:
# Attempt: 0
# Match Duration: 2718
# Attempt: 1
# Match Duration: 2718
# Attempt: 2
# Match Duration: 2718
# Attempt: 3
# Match Duration: 2718
# Attempt: 4
# Match Duration: 2718
# Attempt: 5
# Match Duration: 2718
# Attempt: 6
# Match Duration: 2718
# Attempt: 7
# Match Duration: 2718
# Attempt: 8
# Match Duration: 2718
# Attempt: 9
# Match Duration: 2718
# Attempt: 10
# Match Duration: 2718
# Attempt: 11
# Match Duration: 2718
# Attempt: 12
# Match Duration: 2718
# Attempt: 13
# Match Duration: 2718
# Attempt: 14
# Match Duration: 2718
# Attempt: 15
# Match Duration: 2718
# Attempt: 16
# Match Duration: 2718
# Attempt: 17
# Match Duration: 2718
# Attempt: 18
# Match Duration: 2718
# Attempt: 19
# Match Duration: 2718
# Attempt: 20
# Match Duration: 2718
# Attempt: 21
# Match Duration: 2718
# Attempt: 22
# Match Duration: 2718
# Attempt: 23
# Match Duration: 2718
# Attempt: 24
# Match Duration: 2718
# Attempt: 25
# Match Duration: 2718
# Attempt: 26
# Match Duration: 2718
# Attempt: 27
# Match Duration: 2718
# Attempt: 28
# Match Duration: 2718
# Attempt: 29
# Match Duration: 2718
# Attempt: 30
# Match Duration: 2718
# Attempt: 31
# Match Duration: 2718
# Attempt: 32
# Match Duration: 2718
# Attempt: 33
# Match Duration: 2718
# Attempt: 34
# Match Duration: 2718
# Attempt: 35
# Match Duration: 2718
# Attempt: 36
# Match Duration: 2718
# Attempt: 37
# Match Duration: 2718
# Attempt: 38
# Match Duration: 2718
# Attempt: 39
# Match Duration: 2718
# Attempt: 40
# Match Duration: 2718
# Attempt: 41
# Match Duration: 2718
# Attempt: 42
# Match Duration: 2718
# Attempt: 43
# Match Duration: 2718
# Attempt: 44
# Match Duration: 2718
# Attempt: 45
# Match Duration: 2718
# Attempt: 46
# Match Duration: 2718
# Attempt: 47
# Match Duration: 2718
# Attempt: 48
# Match Duration: 2718
# Attempt: 49
# Match Duration: 2718
# Attempt: 50
# Match Duration: 2718
# Attempt: 51
# Match Duration: 2718
# Attempt: 52
# Match Duration: 2718
# Attempt: 53
# Match Duration: 2718
# Attempt: 54
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Lenovo\Downloads\The Riot API Introductory Guide by iTero Gaming.ipynb Celda 100 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Downloads/The%20Riot%20API%20Introductory%20Guide%20by%20iTero%20Gaming.ipynb#Y201sZmlsZQ%3D%3D?line=3'>4</a> print("Attempt:", i)
#       <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Downloads/The%20Riot%20API%20Introductory%20Guide%20by%20iTero%20Gaming.ipynb#Y201sZmlsZQ%3D%3D?line=4'>5</a> match_data = get_match_data(match_id, mass_region, api_key)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Downloads/The%20Riot%20API%20Introductory%20Guide%20by%20iTero%20Gaming.ipynb#Y201sZmlsZQ%3D%3D?line=5'>6</a> print("Match Duration:", match_data['info']['gameDuration'])
#
# KeyError: 'info'

# %% [markdown]
# The code runs fine and prints the game duration UNTIL the 101st \
#
# So let's inspect what it returned:

# %%
match_data

# %% [markdown]
# A status_code of 429, which means we've exceeded our rate limit
#
# The maximum amount of recent games you can request is 100
#
# So, from start to finish, our code currently can send up to 102 requests \
# 1 to get the summoner names puuid \
# 1 to get the puuids most 100 recent games \
# up to 100 to get data on those games
#
# So, let's update that last function to handle hitting the rate limit

# %%
# Original function to get match ID
def get_match_data(match_id, mass_region, api_key):
    api_url = (
        "https://" + 
        mass_region + 
        ".api.riotgames.com/lol/match/v5/matches/" +
        match_id + 
        "?api_key=" + 
        api_key
    )
    
    resp = requests.get(api_url)
    print("Status Code:", resp.status_code) # We can read the status code straight from the "resp" object
    match_data = resp.json()
    return match_data

# %% [markdown]
# First, let's do the loop again except this time printing the status_code from the "resp" object at each stage
#
# NOTE: Depending on how quickly you're going through the notebook, you may get the error before the 101st attempt \
# since you are still within the 2 minute rate limit from the previous example

# %%
for i in range(120):
    print("Attempt:", i)
    get_match_data(match_id, mass_region, api_key)

# %% [markdown]
# We can now catch the error and prevent it from breaking our code
#
# To do this, we'll use the "time" package, which should be preinstalled

# %%
import time

# %% [markdown]
# It contains a useful function called "sleep", which simply pauses your function for the given amount of seconds

# %%
print("Good Night...")
time.sleep(3)
print("...Good Morning")

# if you decided to change the number to 1000 and now regret it, click Kernel->Interrupt

# %%
# Updated function to sleep until it's succesful
def get_match_data(match_id, mass_region, api_key):
    api_url = (
        "https://" + 
        mass_region + 
        ".api.riotgames.com/lol/match/v5/matches/" +
        match_id + 
        "?api_key=" + 
        api_key
    )
    
    # we need to add this "while" statement so that we continuously loop until it's successful
    while True:
        resp = requests.get(api_url)
        
        # whenever we see a 429, we sleep for 10 seconds and then restart from the top of the "while" loop
        if resp.status_code == 429:
            print("Rate Limit hit, sleeping for 10 seconds")
            time.sleep(10)
            # continue means start the loop again
            continue
            
        # if resp.status_code isn't 429, then we carry on to the end of the function and return the data
        match_data = resp.json()
        return match_data

# %%
# Again, depending on how quick you are running these functions you may immediately hit the sleep
# NOTE: This function takes 2 minutes to run (since it hits the rate limit and then sleeps)
for i in range(101):
    print("Attempt:", i)
    get_match_data(match_id, mass_region, api_key)

# %% [markdown]
# ### Wrapping it all up
#
# With that complete, we can now wrap all our functions together into one:

# %%
def master_function(summoner_name, region, mass_region, no_games, queue_id, api_key):
    puuid = get_puuid(summoner_name, region, api_key)
    match_ids = get_match_ids(puuid, mass_region, no_games, queue_id, api_key)
    df = gather_all_data(puuid, match_ids, mass_region, api_key)
    return df

# %%
summoner_name = "Jack J"
region = "euw1"
mass_region = "EUROPE"
no_games = 100
queue_id = 420

# %%
# Takes 2 minutes to run
df = master_function(summoner_name, region, mass_region, no_games, queue_id, api_key)

# %% [markdown]
# Finally, let's do something useful with the information:

# %%
# print some introductory stuff
print("Hello", summoner_name, "of", region.upper()) # upper simply capitalises the region
print("Here are some interesting statistics about your last 100 solo ranked games")

# create a count column
df['count'] = 1 

# the "agg" allows us to get the average of every column but sum the count                                       # see?
champ_df = df.groupby('champion').agg({'kills': 'mean', 'deaths': 'mean', 'assists': 'mean', 'win': 'mean', 'count': 'sum'})

# we reset in the index so we can still use the "champion" column
champ_df.reset_index(inplace=True)

# we limit it to only champions where you've played 2 or more games
champ_df = champ_df[champ_df['count'] >= 2]

# create a kda column
champ_df['kda'] = (champ_df['kills'] + champ_df['assists']) / champ_df['deaths']

# sort the table by KDA, starting from the highest
champ_df = champ_df.sort_values('kda', ascending=False) # ascending determines whether it's highest to lowest or vice-versa

# assign the first row and last row to a variable so we can print information about it
best_row = champ_df.iloc[0] # .iloc[0] simply takes the first row in dataframe
worst_row = champ_df.iloc[-1] # .iloc[-1] takes the last row in a dataframe

print("Your best KDA is on", best_row['champion'], "with a KDA of", best_row['kda'], "over", best_row['count'], "game/s")
print("Your worst KDA is on", worst_row['champion'], "with a KDA of", worst_row['kda'], "over", worst_row['count'], "game/s")

# sort by count instead
champ_df = champ_df.sort_values('count', ascending=False)

# get your most played champ
row = champ_df.iloc[0]

# assign and format the win rate
win_rate = row['win']
win_rate = str(round(win_rate * 100, 1)) + "%"

print("Your highest played Champion is", row['champion'], "with", row['count'], 'game/s', 
     "and an average Win Rate of", win_rate)

# finally, sort by highest kills in a game (note, not using the champ_df groupby anymore but the raw data)
highest_kills = df.sort_values('kills', ascending=False)
row = highest_kills.iloc[0]
print("Your highest kill game was with", row['champion'], "where you had", row['kills'], "kills")
# Out:
# Hello M0DEST0 of LA1
# Here are some interesting statistics about your last 100 solo ranked games
# Your best KDA is on Mordekaiser with a KDA of 2.3333333333333335 over 6 game/s
# Your worst KDA is on Gwen with a KDA of 1.352941176470588 over 3 game/s
# Your highest played Champion is Mordekaiser with 6 game/s and an average Win Rate of 33.3%
# Your highest kill game was with Caitlyn where you had 13 kills

# %% [markdown]
# ### What now?
#
# Have you finished the tutorial but now have the taste for it and want to do more?
#
# New to Python? If this is your first time coding, I suggest doing an introductory tutorial before anything else. \
# There's tonnes of really good tutorials, guides and videos out there.
#
# If the Python side made sense to you, here's your challenge:
# - Add a new argument to one of the functions, I've set-up a space at the very bottom with everything together for you \
# to play with, get hacking!
# - Create a new function to get a players Champion Mastery, add a line to our final output saying who the highest mastery champion is
# - Jump into the "match timeline" API and get some time specific data, like how many kills you average at 7 minutes
# - From the LEAGUE-V4 API, grab 100 players from a league of your choice. Build a loop that gathers data about all 100 players recent games. Find out what the average number of kills a player has at 15 minutes for each role.
# - BUILD SOMETHING NEW! Share it on our Discord.

# %% [markdown]
# ### What's else is available?
#
# With that, we've concluded our introduction to the Riot API
#
# To help you think of potential ideas, I'll list a few of the popular APIs that you can use:
#
# - How much Mastery a player has on each Champion
# - In-depth game detail for every minute of the game (i.e. how much Gold/XP each player has at 12 minutes)
# - In-depth objective and kill data, like who killed who, when and where
# - Ranked information, such as their current rank for each queue
# - Who is currently in Challenger, Grand Master & Master (& every queue below that too!)
# - And much more...!
#
# There's also further advanced topics that I haven't covered in this introduction but you should be aware of:
#
# - Advanced error handling, 429 Rate Limits is just one of many and each requires it's own logic
# - Speeding up your code! Eventually, you may decide to build something that requires a lot of data and async/multiprocessing/threading will help
# - Building and hosting the frontend of the application
# - Getting Riot to approve your application for public use
#
# I've been Jack J from iTero Gaming, I've hoped you've learnt a lot and I'm excited to see what you build!
#
#
#
#
# You can join our Discord to ask questions, show off what you're building or get inspiration:
# https://discord.gg/DmSUDGEW6V
#
# You can follow me on Twitter to see what I'm using the Riot API for:
# https://twitter.com/JackJGaming
#
# I write a weekly article about statistics/AI/esports/gaming, you can subscribe here: https://medium.com/subscribe/@JackJGaming
#
# Check out the iTero Gaming website to see what we've built:
# https://itero.gg/
